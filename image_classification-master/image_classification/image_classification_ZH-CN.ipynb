# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %% [markdown]
# # 图像分类
#
# 在该项目中，你将会对来自 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图像进行分类。数据集中图片的内容包括飞机（airplane）、狗（dogs）、猫（cats）及其他物体。你需要处理这些图像，接着对所有的样本训练一个卷积神经网络。
#
# 具体而言，在项目中你要对图像进行正规化处理（normalization)，同时还要对图像的标签进行 one-hot 编码。接着你将会应用到你所学的技能来搭建一个具有卷积层、最大池化（Max Pooling）层、Dropout  层及全连接（fully connected）层的神经网络。最后，你会训练你的神经网络，会得到你神经网络在样本图像上的预测结果。
#
# ## 下载数据
#
# 运行如下代码下载 [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %% [markdown]
# ## 探索数据集
#
#
# 为防止在运行过程中内存不足的问题，该数据集已经事先被分成了5批（batch），名为`data_batch_1`、`data_batch_2`等。每一批中都含有 *图像* 及对应的 *标签*，都是如下类别中的一种：
#
# * 飞机
# * 汽车
# * 鸟
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船
# * 卡车
#
# 理解数据集也是对数据进行预测的一部分。修改如下代码中的 `batch_id` 和 `sample_id`，看看输出的图像是什么样子。其中，`batch_id` 代表着批次数（1-5），`sample_id` 代表着在该批内图像及标签的编号。
#
# 你可以尝试回答如下问题：
# * 可能出现的 *标签* 都包括哪些？
# * 图像数据的取值范围是多少？
# * *标签* 的排列顺序是随机的还是有序的？
#
# 对这些问题的回答，会有助于更好地处理数据，并能更好地进行预测。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %% [markdown]
# ## 图像预处理功能的实现
# ### 正规化
#
# 在如下的代码中，修改 `normalize` 函数，使之能够对输入的图像数据 `x` 进行处理，输出一个经过正规化的、Numpy array 格式的图像数据。
#
# **注意：**
# 处理后的值应当在 $[0,1]$ 的范围之内。返回值应当和输入值具有相同的形状。

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
  
    return (x - np.min(x))/(np.max(x) - np.min(x))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %% [markdown]
# ### One-hot 编码
#
# 在如下代码中，你将继续实现预处理的功能，实现一个 `one_hot_encode` 函数。函数的输入 `x` 是 *标签* 构成的列表，返回值是经过 One_hot 处理过后的这列 *标签* 对应的 One_hot 编码，以 Numpy array 储存。其中，*标签* 的取值范围从0到9。每次调用该函数时，对相同的标签值，它输出的编码也是相同的。请确保在函数外保存编码的映射（map of encodings）。
#
# **提示：**
#
# 你可以尝试使用 sklearn preprocessing 模块中的 `LabelBinarizer` 函数。

# %%
from sklearn import preprocessing
import numpy as np
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    lb = preprocessing.LabelBinarizer()
    lb.fit(np.arange(10))
    result = lb.transform(x)

    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ### 随机打乱数据
#
# 正如你在上方探索数据部分所看到的，样本的顺序已经被随机打乱了。尽管再随机处理一次也没问题，不过对于该数据我们没必要再进行一次相关操作了。

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %% [markdown]
# ## 对所有图像数据进行预处理并保存结果
#
# 运行如下代码，它将会预处理所有的 CIFAR-10 数据并将它另存为文件。此外，如下的代码还将会把 10% 的训练数据留出作为验证数据。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %% [markdown]
# # 检查点
#
# 这是你的首个检查点。因为预处理完的数据已经被保存到硬盘上了，所以如果你需要回顾或重启该 notebook，你可以在这里重新开始。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %% [markdown]
# ## 搭建神经网络
#
# 为搭建神经网络，你需要将搭建每一层的过程封装到一个函数中。大部分的代码你在函数外已经见过。为能够更透彻地测试你的代码，我们要求你把每一层都封装到一个函数中。这能够帮助我们给予你更好的回复，同时还能让我们使用 unittests 在你提交报告前检测出你项目中的小问题。
#
# >**注意：** 如果你时间紧迫，那么在该部分我们为你提供了一个便捷方法。在接下来的一些问题中，你可以使用来自 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的函数来搭建各层，不过不可以用他们搭建卷积-最大池化层。TF Layers 和 Keras 及 TFLean 中对层的抽象比较相似，所以你应该很容易上手。
#
# >
#
#
# However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# 不过，如果你希望能够更多地实践，我们希望你能够在**不**使用 TF Layers 的情况下解决所有问题。你依然**能**使用来自其他包但和 layers 中重名的函数。例如，你可以使用 TF Neural Network 版本的 `conv_2d
#
# 让我们开始吧！
#
# ### 输入
#
# 神经网络需要能够读取图像数据、经 one-hot 编码之后的标签及 dropout 中的保留概率。修改如下函数：
#
# * 修改 `neural_net_image_input` 函数：
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)。
#  * 使用 `image_shape` 设定形状，设定批大小（batch size)为 `None`。
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 `Name` 参数，命名该 TensorFlow placeholder 为 "x"。
# * 修改 `neural_net_label_input` 函数：
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)。
#  * 使用 `n_classes` 设定形状，设定批大小（batch size)为 `None`。
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 `Name` 参数，命名该 TensorFlow placeholder 为 "y"。
# * 修改 `neural_net_keep_prob_input` 函数：
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 作为 dropout 的保留概率（keep probability）。
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 `Name` 参数，命名该 TensorFlow placeholder 为 "keep_prob"。
#
# 我们会在项目最后使用这些名字，来载入你储存的模型。
#
# **注意：**在 TensorFlow 中，对形状设定为 `None`，能帮助设定一个动态的大小。

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name='x')
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, shape=(None, n_classes), name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    kp = tf.placeholder(tf.float32, shape=None, name='keep_prob')
    return kp


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %% [markdown]
# ### 卷积-最大池（Convolution and Max Pooling）化层
#
# 卷积层在图像处理中取得了不小的成功。在这部分的代码中，你需要修改 `conv2d_maxpool` 函数来先后实现卷积及最大池化的功能。
#
# * 使用 `conv_ksize`、`conv_num_outputs` 及 `x_tensor` 来创建权重（weight）及偏差（bias）变量。
# * 对 `x_tensor` 进行卷积，使用 `conv_strides` 及*权重*。
#  * 我们建议使用 SAME padding，不过你也可尝试其他 padding 模式。
# * 加上*偏差*。
# * 对卷积结果加上一个非线性函数作为激活层。
# * 基于 `pool_kszie` 及 `pool_strides` 进行最大池化。
#  * 我们建议使用 SAME padding，不过你也可尝试其他 padding 模式。
#
# **注意：**
# 你**不**可以使用来自 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的函数来实现**这一层**的功能。但是你可以使用 TensorFlow 的[Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn)包。
#
# 对于如上的快捷方法，你在**其他层**中可以尝试使用。
#
#
# **提示：**
# 当你在 Python 中希望展开（unpacking）某个变量的值作为函数的参数，你可以参考 [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) 运算符。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # 权重
    shape = x_tensor.get_shape().as_list()[3]
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], shape, conv_num_outputs]))
    
    # 偏置
    bias = tf.Variable(tf.zeros([conv_num_outputs]))
    
    # 卷积层
    strides = [1, conv_strides[0], conv_strides[1], 1]
    conv2d = tf.nn.conv2d(x_tensor, weight, strides, padding='SAME')
    output = tf.nn.sigmoid(tf.add(conv2d, bias))
    
    # 最大池化
    ksize = [1, pool_ksize[0], pool_ksize[1], 1]
    strides = [1, pool_strides[0], pool_strides[1], 1]
    max_pool = tf.nn.max_pool(output, ksize, strides, padding='SAME')                    
    
    return max_pool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %% [markdown]
# ### 展开层
#
# 修改 `flatten` 函数，来将4维的输入张量 `x_tensor` 转换为一个二维的张量。输出的形状应当是 `(Batch Size, Flattened Image Size)`。
# 快捷方法：你可以使用来自 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的函数来实现该功能。不过你也可以只使用 TensorFlow 包中的函数来挑战自己。

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    #改变数据结构
    shape = x_tensor.shape.as_list()
    shapes = shape[1]*shape[2]*shape[3]
    return tf.reshape(x_tensor, [-1, shapes])
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %% [markdown]
# ### 全连接层
#
# 修改 `fully_conn` 函数，来对形如 `(batch Size, num_outputs)` 的输入 `x_tensor` 应用一个全连接层。快捷方法：你可以使用来自 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的函数来实现该功能。不过你也可以只使用 TensorFlow 包中的函数来挑战自己。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    # 全连接层
    # 权重
    shape = x_tensor.shape.as_list()
    weight = tf.Variable(tf.truncated_normal([shape[1], num_outputs]))
    
    # 偏置
    bias = tf.Variable(tf.zeros([num_outputs]))
    
    # 输出
    out = tf.add(tf.matmul(x_tensor, weight), bias)
    return tf.nn.sigmoid(out)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %% [markdown]
# ### 输出层
#
# 修改 `output` 函数，来对形如 `(batch Size, num_outputs)` 的输入 `x_tensor` 应用一个全连接层。快捷方法：你可以使用来自 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的函数来实现该功能。不过你也可以只使用 TensorFlow 包中的函数来挑战自己。
#
# **注意：**
# 激活函数、softmax 或者交叉熵（corss entropy）**不**应被加入到该层。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    # 权重
    shape = x_tensor.shape.as_list()
    weight = tf.Variable(tf.truncated_normal([shape[1], num_outputs]))
    
    # 偏置
    bias = tf.Variable(tf.zeros([num_outputs]))
    
    # 输出
    output = tf.add(tf.matmul(x_tensor, weight), bias)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %% [markdown]
# ### 创建卷积模型
#
# 修改 `conv_net` 函数，使之能够生成一个卷积神经网络模型。该函数的输入为一批图像数据 `x`，输出为 logits。在函数中，使用上方你修改的创建各种层的函数来创建该模型：
#
# * 使用 1 到 3 个卷积-最大池化层
# * 使用一个展开层
# * 使用 1 到 3 个全连接层
# * 使用一个输出层
# * 返回呼出结果
# * 在一个或多个层上使用 [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)，对应的保留概率为 `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    # 3层卷积
    conv = conv2d_maxpool(x, 32, (4,4), (1,1), (2,2), (2,2))
    conv_pool = conv2d_maxpool(conv, 64, (4,4), (1,1), (2,2), (2,2))
    conv_out = conv2d_maxpool(conv_pool, 128, (2,2), (1,1), (2,2), (2,2))
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x_flat = flatten(conv_out)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    # 2层全连接
    x_fully = fully_conn(x_flat, 512)
    x_dropout = tf.nn.dropout(x_fully, keep_prob)
    x_fc = fully_conn(x_dropout, 64)
    x_out = tf.nn.dropout(x_fc, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    y_output = output(x_out, 10)
    
    # TODO: return output
    return y_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %% [markdown]
# ## 训练该神经网络
#
# ### 最优化
#
# 修改 `train_neural_network` 函数以执行单次最优化。该最优化过程应在一个 `session` 中使用 `optimizer` 来进行该过程，它的 `feed_dict` 包括：
# * `x` 代表输入图像
# * `y` 代表*标签*
# * `keep_prob` 为 Dropout 过程中的保留概率
#
# 对每批数据该函数都会被调用，因而 `tf.global_variables_initializer()` 已经被调用过。
#
# 注意：该函数并不要返回某个值，它只对神经网络进行最优化。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %% [markdown]
# ### 显示状态
#
# 修改 `print_stats` 函数来打印 loss 值及验证准确率。 使用全局的变量 `valid_features` 及 `valid_labels` 来计算验证准确率。 设定保留概率为 1.0 来计算 loss 值及验证准确率。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    
    loss, train_accuracy = session.run([cost,accuracy], feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    valid_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print ('Loss: {:>10.4f}, Train Accuracy: {:>10.4f}, Validation Accuracy: {:.4f}'.format(loss, train_accuracy, valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %% [markdown]
# ### 超参数调节
#
# 你需要调节如下的参数：
# * 设定 `epoches` 为模型停止学习或开始过拟合时模型的迭代次数。
# * 设定 `batch_size` 为你内存能支持的最大值。一般我们设定该值为：
#  * 64
#  * 128
#  * 256
#  * ...
# * 设定 `keep_probability` 为在 dropout 过程中保留一个节点的概率。

# %%
# TODO: Tune Parameters
epochs = 400
batch_size = 512
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %% [markdown]
# ### 对单批 CIFAR-10 数据进行训练
#
# 相比于在所有 CIFAR-10 数据上训练神经网络，我们首先使用一批数据进行训练。这会帮助你在调节模型提高精度的过程中节省时间。当最终的验证精度超过 50% 之后，你就可以前往下一节在所有数据上运行该模型了。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.8985, Train Accuracy:     0.1081, Validation Accuracy: 0.1064
# Epoch  2, CIFAR-10 Batch 1:  Loss:     3.0714, Train Accuracy:     0.0845, Validation Accuracy: 0.1052
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.7309, Train Accuracy:     0.1115, Validation Accuracy: 0.1104
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.7075, Train Accuracy:     0.1081, Validation Accuracy: 0.1064
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.6000, Train Accuracy:     0.1081, Validation Accuracy: 0.1058
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.5843, Train Accuracy:     0.1284, Validation Accuracy: 0.1256
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.5085, Train Accuracy:     0.0777, Validation Accuracy: 0.1230
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.4287, Train Accuracy:     0.1250, Validation Accuracy: 0.1278
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.4265, Train Accuracy:     0.1216, Validation Accuracy: 0.1100
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.3957, Train Accuracy:     0.1351, Validation Accuracy: 0.1074
# Epoch 11, CIFAR-10 Batch 1:  Loss:     2.3729, Train Accuracy:     0.1453, Validation Accuracy: 0.1506
# Epoch 12, CIFAR-10 Batch 1:  Loss:     2.3387, Train Accuracy:     0.1486, Validation Accuracy: 0.1370
# Epoch 13, CIFAR-10 Batch 1:  Loss:     2.3003, Train Accuracy:     0.1824, Validation Accuracy: 0.1602
# Epoch 14, CIFAR-10 Batch 1:  Loss:     2.2873, Train Accuracy:     0.1655, Validation Accuracy: 0.1682
# Epoch 15, CIFAR-10 Batch 1:  Loss:     2.3030, Train Accuracy:     0.1486, Validation Accuracy: 0.1536
# Epoch 16, CIFAR-10 Batch 1:  Loss:     2.2913, Train Accuracy:     0.1453, Validation Accuracy: 0.1524
# Epoch 17, CIFAR-10 Batch 1:  Loss:     2.2988, Train Accuracy:     0.1486, Validation Accuracy: 0.1616
# Epoch 18, CIFAR-10 Batch 1:  Loss:     2.2980, Train Accuracy:     0.1351, Validation Accuracy: 0.1260
# Epoch 19, CIFAR-10 Batch 1:  Loss:     2.2781, Train Accuracy:     0.1486, Validation Accuracy: 0.1562
# Epoch 20, CIFAR-10 Batch 1:  Loss:     2.2725, Train Accuracy:     0.1115, Validation Accuracy: 0.1414
# Epoch 21, CIFAR-10 Batch 1:  Loss:     2.2778, Train Accuracy:     0.1047, Validation Accuracy: 0.1264
# Epoch 22, CIFAR-10 Batch 1:  Loss:     2.2457, Train Accuracy:     0.1182, Validation Accuracy: 0.1462
# Epoch 23, CIFAR-10 Batch 1:  Loss:     2.2260, Train Accuracy:     0.1250, Validation Accuracy: 0.1546
# Epoch 24, CIFAR-10 Batch 1:  Loss:     2.2216, Train Accuracy:     0.1385, Validation Accuracy: 0.1468
# Epoch 25, CIFAR-10 Batch 1:  Loss:     2.2210, Train Accuracy:     0.1081, Validation Accuracy: 0.1546
# Epoch 26, CIFAR-10 Batch 1:  Loss:     2.2169, Train Accuracy:     0.1216, Validation Accuracy: 0.1470
# Epoch 27, CIFAR-10 Batch 1:  Loss:     2.2237, Train Accuracy:     0.1216, Validation Accuracy: 0.1594
# Epoch 28, CIFAR-10 Batch 1:  Loss:     2.2161, Train Accuracy:     0.1182, Validation Accuracy: 0.1606
# Epoch 29, CIFAR-10 Batch 1:  Loss:     2.2170, Train Accuracy:     0.1182, Validation Accuracy: 0.1592
# Epoch 30, CIFAR-10 Batch 1:  Loss:     2.1923, Train Accuracy:     0.1149, Validation Accuracy: 0.1624
# Epoch 31, CIFAR-10 Batch 1:  Loss:     2.1732, Train Accuracy:     0.1520, Validation Accuracy: 0.1716
# Epoch 32, CIFAR-10 Batch 1:  Loss:     2.1920, Train Accuracy:     0.1284, Validation Accuracy: 0.1660
# Epoch 33, CIFAR-10 Batch 1:  Loss:     2.1319, Train Accuracy:     0.2196, Validation Accuracy: 0.2182
# Epoch 34, CIFAR-10 Batch 1:  Loss:     2.1241, Train Accuracy:     0.2061, Validation Accuracy: 0.2052
# Epoch 35, CIFAR-10 Batch 1:  Loss:     2.0870, Train Accuracy:     0.1892, Validation Accuracy: 0.2238
# Epoch 36, CIFAR-10 Batch 1:  Loss:     2.1121, Train Accuracy:     0.1622, Validation Accuracy: 0.1986
# Epoch 37, CIFAR-10 Batch 1:  Loss:     2.1183, Train Accuracy:     0.1858, Validation Accuracy: 0.1942
# Epoch 38, CIFAR-10 Batch 1:  Loss:     2.0561, Train Accuracy:     0.1993, Validation Accuracy: 0.2192
# Epoch 39, CIFAR-10 Batch 1:  Loss:     2.0977, Train Accuracy:     0.1723, Validation Accuracy: 0.2120
# Epoch 40, CIFAR-10 Batch 1:  Loss:     2.0740, Train Accuracy:     0.2162, Validation Accuracy: 0.2264
# Epoch 41, CIFAR-10 Batch 1:  Loss:     2.0952, Train Accuracy:     0.1959, Validation Accuracy: 0.2134
# Epoch 42, CIFAR-10 Batch 1:  Loss:     2.0273, Train Accuracy:     0.2162, Validation Accuracy: 0.2274
# Epoch 43, CIFAR-10 Batch 1:  Loss:     2.0354, Train Accuracy:     0.2230, Validation Accuracy: 0.2312
# Epoch 44, CIFAR-10 Batch 1:  Loss:     2.0228, Train Accuracy:     0.2568, Validation Accuracy: 0.2356
# Epoch 45, CIFAR-10 Batch 1:  Loss:     2.0140, Train Accuracy:     0.2399, Validation Accuracy: 0.2506
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1
# Epoch 126, CIFAR-10 Batch 1:  Loss:     1.6654, Train Accuracy:     0.3514, Validation Accuracy: 0.3892
# Epoch 127, CIFAR-10 Batch 1:  Loss:     1.6603, Train Accuracy:     0.3649, Validation Accuracy: 0.3816
# Epoch 128, CIFAR-10 Batch 1:  Loss:     1.6733, Train Accuracy:     0.3547, Validation Accuracy: 0.3852
# Epoch 129, CIFAR-10 Batch 1:  Loss:     1.6612, Train Accuracy:     0.3311, Validation Accuracy: 0.3804
# Epoch 130, CIFAR-10 Batch 1:  Loss:     1.7074, Train Accuracy:     0.3412, Validation Accuracy: 0.3830
# Epoch 131, CIFAR-10 Batch 1:  Loss:     1.6573, Train Accuracy:     0.3750, Validation Accuracy: 0.3910
# Epoch 132, CIFAR-10 Batch 1:  Loss:     1.6611, Train Accuracy:     0.3682, Validation Accuracy: 0.3918
# Epoch 133, CIFAR-10 Batch 1:  Loss:     1.6273, Train Accuracy:     0.3784, Validation Accuracy: 0.3976
# Epoch 134, CIFAR-10 Batch 1:  Loss:     1.6068, Train Accuracy:     0.3851, Validation Accuracy: 0.3938
# Epoch 135, CIFAR-10 Batch 1:  Loss:     1.6456, Train Accuracy:     0.3378, Validation Accuracy: 0.3906
# Epoch 136, CIFAR-10 Batch 1:  Loss:     1.6087, Train Accuracy:     0.3986, Validation Accuracy: 0.4014
# Epoch 137, CIFAR-10 Batch 1:  Loss:     1.6077, Train Accuracy:     0.3851, Validation Accuracy: 0.4014
# Epoch 138, CIFAR-10 Batch 1:  Loss:     1.6010, Train Accuracy:     0.3818, Validation Accuracy: 0.3940
# Epoch 139, CIFAR-10 Batch 1:  Loss:     1.6222, Train Accuracy:     0.3615, Validation Accuracy: 0.3902
# Epoch 140, CIFAR-10 Batch 1:  Loss:     1.6095, Train Accuracy:     0.3378, Validation Accuracy: 0.3994
# Epoch 141, CIFAR-10 Batch 1:  Loss:     1.6239, Train Accuracy:     0.3784, Validation Accuracy: 0.3920
# Epoch 142, CIFAR-10 Batch 1:  Loss:     1.5951, Train Accuracy:     0.3581, Validation Accuracy: 0.3962
# Epoch 143, CIFAR-10 Batch 1:  Loss:     1.5831, Train Accuracy:     0.3885, Validation Accuracy: 0.3964
# Epoch 144, CIFAR-10 Batch 1:  Loss:     1.6005, Train Accuracy:     0.3986, Validation Accuracy: 0.3976
# Epoch 145, CIFAR-10 Batch 1:  Loss:     1.5918, Train Accuracy:     0.3919, Validation Accuracy: 0.3948
# Epoch 146, CIFAR-10 Batch 1:  Loss:     1.5886, Train Accuracy:     0.3750, Validation Accuracy: 0.4006
# Epoch 147, CIFAR-10 Batch 1:  Loss:     1.6142, Train Accuracy:     0.4122, Validation Accuracy: 0.4066
# Epoch 148, CIFAR-10 Batch 1:  Loss:     1.5885, Train Accuracy:     0.3716, Validation Accuracy: 0.4156
# Epoch 149, CIFAR-10 Batch 1:  Loss:     1.5802, Train Accuracy:     0.3716, Validation Accuracy: 0.3998
# Epoch 150, CIFAR-10 Batch 1:  Loss:     1.5882, Train Accuracy:     0.3818, Validation Accuracy: 0.4038
# Epoch 151, CIFAR-10 Batch 1:  Loss:     1.5651, Train Accuracy:     0.4020, Validation Accuracy: 0.4088
# Epoch 152, CIFAR-10 Batch 1:  Loss:     1.5695, Train Accuracy:     0.3953, Validation Accuracy: 0.3950
# Epoch 153, CIFAR-10 Batch 1:  Loss:     1.5604, Train Accuracy:     0.4155, Validation Accuracy: 0.4054
# Epoch 191, CIFAR-10 Batch 1:  Loss:     1.4317, Train Accuracy:     0.4595, Validation Accuracy: 0.4326
# Epoch 192, CIFAR-10 Batch 1:  Loss:     1.4157, Train Accuracy:     0.4831, Validation Accuracy: 0.4326
# Epoch 193, CIFAR-10 Batch 1:  Loss:     1.4313, Train Accuracy:     0.4966, Validation Accuracy: 0.4234
# Epoch 194, CIFAR-10 Batch 1:  Loss:     1.4051, Train Accuracy:     0.5000, Validation Accuracy: 0.4308
# Epoch 195, CIFAR-10 Batch 1:  Loss:     1.4150, Train Accuracy:     0.4696, Validation Accuracy: 0.4336
# Epoch 196, CIFAR-10 Batch 1:  Loss:     1.4203, Train Accuracy:     0.4730, Validation Accuracy: 0.4320
# Epoch 197, CIFAR-10 Batch 1:  Loss:     1.4421, Train Accuracy:     0.5000, Validation Accuracy: 0.4282
# Epoch 198, CIFAR-10 Batch 1:  Loss:     1.4076, Train Accuracy:     0.4797, Validation Accuracy: 0.4400
# Epoch 199, CIFAR-10 Batch 1:  Loss:     1.4023, Train Accuracy:     0.5034, Validation Accuracy: 0.4416
# Epoch 200, CIFAR-10 Batch 1:  Loss:     1.4026, Train Accuracy:     0.4764, Validation Accuracy: 0.4352
# Epoch 201, CIFAR-10 Batch 1:  Loss:     1.3995, Train Accuracy:     0.4797, Validation Accuracy: 0.4358
# Epoch 202, CIFAR-10 Batch 1:  Loss:     1.4015, Train Accuracy:     0.4730, Validation Accuracy: 0.4318
# Epoch 203, CIFAR-10 Batch 1:  Loss:     1.4077, Train Accuracy:     0.4899, Validation Accuracy: 0.4396
# Epoch 204, CIFAR-10 Batch 1:  Loss:     1.3947, Train Accuracy:     0.5169, Validation Accuracy: 0.4464
# Epoch 205, CIFAR-10 Batch 1:  Loss:     1.3709, Train Accuracy:     0.5034, Validation Accuracy: 0.4400
# Epoch 206, CIFAR-10 Batch 1:  Loss:     1.3933, Train Accuracy:     0.5101, Validation Accuracy: 0.4494
# Epoch 207, CIFAR-10 Batch 1:  Loss:     1.3791, Train Accuracy:     0.4899, Validation Accuracy: 0.4528
# Epoch 208, CIFAR-10 Batch 1:  Loss:     1.3807, Train Accuracy:     0.5034, Validation Accuracy: 0.4408
# Epoch 209, CIFAR-10 Batch 1:  Loss:     1.4080, Train Accuracy:     0.4696, Validation Accuracy: 0.4422
# Epoch 210, CIFAR-10 Batch 1:  Loss:     1.3932, Train Accuracy:     0.4865, Validation Accuracy: 0.4386
# Epoch 211, CIFAR-10 Batch 1:  Loss:     1.3620, Train Accuracy:     0.5000, Validation Accuracy: 0.4374
# Epoch 212, CIFAR-10 Batch 1:  Loss:     1.3773, Train Accuracy:     0.4797, Validation Accuracy: 0.4454
# Epoch 213, CIFAR-10 Batch 1:  Loss:     1.3736, Train Accuracy:     0.4899, Validation Accuracy: 0.4390
# Epoch 214, CIFAR-10 Batch 1:  Loss:     1.3815, Train Accuracy:     0.4966, Validation Accuracy: 0.4306
# Epoch 215, CIFAR-10 Batch 1:  Loss:     1.3578, Train Accuracy:     0.5034, Validation Accuracy: 0.4452
# Epoch 216, CIFAR-10 Batch 1:  Loss:     1.3458, Train Accuracy:     0.5169, Validation Accuracy: 0.4448
# Epoch 217, CIFAR-10 Batch 1:  Loss:     1.3638, Train Accuracy:     0.5236, Validation Accuracy: 0.4410
# Epoch 218, CIFAR-10 Batch 1:  Loss:     1.3355, Train Accuracy:     0.5203, Validation Accuracy: 0.4482
# Epoch 219, CIFAR-10 Batch 1:  Loss:     1.3421, Train Accuracy:     0.4899, Validation Accuracy: 0.4452
# Epoch 220, CIFAR-10 Batch 1:  Loss:     1.3556, Train Accuracy:     0.5000, Validation Accuracy: 0.4492
# Epoch 221, CIFAR-10 Batch 1:  Loss:     1.3530, Train Accuracy:     0.5135, Validation Accuracy: 0.4454
# Epoch 222, CIFAR-10 Batch 1:  Loss:     1.3490, Train Accuracy:     0.5169, Validation Accuracy: 0.4364
# Epoch 223, CIFAR-10 Batch 1:  Loss:     1.3999, Train Accuracy:     0.4764, Validation Accuracy: 0.4380
# Epoch 224, CIFAR-10 Batch 1:  Loss:     1.3119, Train Accuracy:     0.5135, Validation Accuracy: 0.4534
# Epoch 225, CIFAR-10 Batch 1:  Loss:     1.3167, Train Accuracy:     0.5236, Validation Accuracy: 0.4470
# Epoch 226, CIFAR-10 Batch 1:  Loss:     1.3851, Train Accuracy:     0.4865, Validation Accuracy: 0.4320
# Epoch 227, CIFAR-10 Batch 1:  Loss:     1.3917, Train Accuracy:     0.4831, Validation Accuracy: 0.4260
# Epoch 228, CIFAR-10 Batch 1:  Loss:     1.3389, Train Accuracy:     0.5135, Validation Accuracy: 0.4430
# Epoch 229, CIFAR-10 Batch 1:  Loss:     1.2893, Train Accuracy:     0.5574, Validation Accuracy: 0.4518
# Epoch 230, CIFAR-10 Batch 1:  Loss:     1.2983, Train Accuracy:     0.5405, Validation Accuracy: 0.4484
# Epoch 231, CIFAR-10 Batch 1:  Loss:     1.2852, Train Accuracy:     0.5574, Validation Accuracy: 0.4548
# Epoch 232, CIFAR-10 Batch 1:  Loss:     1.2645, Train Accuracy:     0.5541, Validation Accuracy: 0.4574
# Epoch 233, CIFAR-10 Batch 1:  Loss:     1.2905, Train Accuracy:     0.5642, Validation Accuracy: 0.4548
# Epoch 234, CIFAR-10 Batch 1:  Loss:     1.2955, Train Accuracy:     0.5507, Validation Accuracy: 0.4564
# Epoch 235, CIFAR-10 Batch 1:  Loss:     1.3221, Train Accuracy:     0.5338, Validation Accuracy: 0.4466
# Epoch 236, CIFAR-10 Batch 1:  Loss:     1.3036, Train Accuracy:     0.5236, Validation Accuracy: 0.4572
# Epoch 237, CIFAR-10 Batch 1:  Loss:     1.2981, Train Accuracy:     0.5676, Validation Accuracy: 0.4566
# Epoch 238, CIFAR-10 Batch 1:  Loss:     1.3070, Train Accuracy:     0.5304, Validation Accuracy: 0.4468
# Epoch 239, CIFAR-10 Batch 1:  Loss:     1.3052, Train Accuracy:     0.5101, Validation Accuracy: 0.4516
# Epoch 240, CIFAR-10 Batch 1:  Loss:     1.2990, Train Accuracy:     0.5473, Validation Accuracy: 0.4578
# Epoch 241, CIFAR-10 Batch 1:  Loss:     1.3216, Train Accuracy:     0.5236, Validation Accuracy: 0.4494
# Epoch 242, CIFAR-10 Batch 1:  Loss:     1.2958, Train Accuracy:     0.5473, Validation Accuracy: 0.4518
# Epoch 243, CIFAR-10 Batch 1:  Loss:     1.3477, Train Accuracy:     0.5203, Validation Accuracy: 0.4372
# Epoch 244, CIFAR-10 Batch 1:  Loss:     1.3689, Train Accuracy:     0.5203, Validation Accuracy: 0.4422
# Epoch 245, CIFAR-10 Batch 1:  Loss:     1.2893, Train Accuracy:     0.5372, Validation Accuracy: 0.4564
# Epoch 246, CIFAR-10 Batch 1:  Loss:     1.2649, Train Accuracy:     0.5845, Validation Accuracy: 0.4540
# Epoch 247, CIFAR-10 Batch 1:  Loss:     1.2695, Train Accuracy:     0.5473, Validation Accuracy: 0.4650
# Epoch 248, CIFAR-10 Batch 1:  Loss:     1.2656, Train Accuracy:     0.5541, Validation Accuracy: 0.4572
# Epoch 249, CIFAR-10 Batch 1:  Loss:     1.3124, Train Accuracy:     0.5405, Validation Accuracy: 0.4484
# Epoch 250, CIFAR-10 Batch 1:  Loss:     1.2466, Train Accuracy:     0.5473, Validation Accuracy: 0.4636
# Epoch 251, CIFAR-10 Batch 1:  Loss:     1.2202, Train Accuracy:     0.5878, Validation Accuracy: 0.4648
# Epoch 252, CIFAR-10 Batch 1:  Loss:     1.2161, Train Accuracy:     0.5777, Validation Accuracy: 0.4616
# Epoch 253, CIFAR-10 Batch 1:  Loss:     1.2519, Train Accuracy:     0.5642, Validation Accuracy: 0.4662
# Epoch 254, CIFAR-10 Batch 1:  Loss:     1.2502, Train Accuracy:     0.5676, Validation Accuracy: 0.4544
# Epoch 255, CIFAR-10 Batch 1:  Loss:     1.2188, Train Accuracy:     0.5811, Validation Accuracy: 0.4646
# Epoch 256, CIFAR-10 Batch 1:  Loss:     1.2204, Train Accuracy:     0.5777, Validation Accuracy: 0.4706
# Epoch 257, CIFAR-10 Batch 1:  Loss:     1.2214, Train Accuracy:     0.5811, Validation Accuracy: 0.4608
# Epoch 258, CIFAR-10 Batch 1:  Loss:     1.1892, Train Accuracy:     0.6047, Validation Accuracy: 0.4722
# Epoch 259, CIFAR-10 Batch 1:  Loss:     1.2027, Train Accuracy:     0.5777, Validation Accuracy: 0.4684
# Epoch 260, CIFAR-10 Batch 1:  Loss:     1.2098, Train Accuracy:     0.5743, Validation Accuracy: 0.4734
# Epoch 261, CIFAR-10 Batch 1:  Loss:     1.1970, Train Accuracy:     0.5811, Validation Accuracy: 0.4656
# Epoch 262, CIFAR-10 Batch 1:  Loss:     1.2311, Train Accuracy:     0.5777, Validation Accuracy: 0.4638
# Epoch 263, CIFAR-10 Batch 1:  Loss:     1.1961, Train Accuracy:     0.5912, Validation Accuracy: 0.4686
# Epoch 264, CIFAR-10 Batch 1:  Loss:     1.1838, Train Accuracy:     0.5743, Validation Accuracy: 0.4648
# Epoch 265, CIFAR-10 Batch 1:  Loss:     1.1952, Train Accuracy:     0.5912, Validation Accuracy: 0.4764
# Epoch 266, CIFAR-10 Batch 1:  Loss:     1.2080, Train Accuracy:     0.5878, Validation Accuracy: 0.4528
# Epoch 267, CIFAR-10 Batch 1:  Loss:     1.1800, Train Accuracy:     0.5709, Validation Accuracy: 0.4634
# Epoch 268, CIFAR-10 Batch 1:  Loss:     1.1721, Train Accuracy:     0.5912, Validation Accuracy: 0.4726
# Epoch 269, CIFAR-10 Batch 1:  Loss:     1.1672, Train Accuracy:     0.6014, Validation Accuracy: 0.4744
# Epoch 270, CIFAR-10 Batch 1:  Loss:     1.1728, Train Accuracy:     0.5811, Validation Accuracy: 0.4680
# Epoch 271, CIFAR-10 Batch 1:  Loss:     1.1713, Train Accuracy:     0.6081, Validation Accuracy: 0.4678
# Epoch 272, CIFAR-10 Batch 1:  Loss:     1.1660, Train Accuracy:     0.6115, Validation Accuracy: 0.4680
# Epoch 273, CIFAR-10 Batch 1:  Loss:     1.1739, Train Accuracy:     0.5811, Validation Accuracy: 0.4768
# Epoch 274, CIFAR-10 Batch 1:  Loss:     1.1780, Train Accuracy:     0.6182, Validation Accuracy: 0.4718
# Epoch 275, CIFAR-10 Batch 1:  Loss:     1.1742, Train Accuracy:     0.5878, Validation Accuracy: 0.4814
# Epoch 276, CIFAR-10 Batch 1:  Loss:     1.1931, Train Accuracy:     0.5878, Validation Accuracy: 0.4486
# Epoch 277, CIFAR-10 Batch 1:  Loss:     1.1499, Train Accuracy:     0.5912, Validation Accuracy: 0.4686
# Epoch 278, CIFAR-10 Batch 1:  Loss:     1.1858, Train Accuracy:     0.5709, Validation Accuracy: 0.4776
# Epoch 279, CIFAR-10 Batch 1:  Loss:     1.1518, Train Accuracy:     0.6182, Validation Accuracy: 0.4734
# Epoch 280, CIFAR-10 Batch 1:  Loss:     1.1211, Train Accuracy:     0.6115, Validation Accuracy: 0.4738
# Epoch 281, CIFAR-10 Batch 1:  Loss:     1.1519, Train Accuracy:     0.5946, Validation Accuracy: 0.4642
# Epoch 282, CIFAR-10 Batch 1:  Loss:     1.1417, Train Accuracy:     0.5946, Validation Accuracy: 0.4768
# Epoch 283, CIFAR-10 Batch 1:  Loss:     1.1328, Train Accuracy:     0.6014, Validation Accuracy: 0.4664
# Epoch 284, CIFAR-10 Batch 1:  Loss:     1.1284, Train Accuracy:     0.6182, Validation Accuracy: 0.4752
# Epoch 285, CIFAR-10 Batch 1:  Loss:     1.1063, Train Accuracy:     0.6182, Validation Accuracy: 0.4768
# Epoch 286, CIFAR-10 Batch 1:  Loss:     1.1089, Train Accuracy:     0.6216, Validation Accuracy: 0.4854
# Epoch 287, CIFAR-10 Batch 1:  Loss:     1.0971, Train Accuracy:     0.6182, Validation Accuracy: 0.4776
# Epoch 288, CIFAR-10 Batch 1:  Loss:     1.1292, Train Accuracy:     0.6014, Validation Accuracy: 0.4830
# Epoch 289, CIFAR-10 Batch 1:  Loss:     1.1012, Train Accuracy:     0.6250, Validation Accuracy: 0.4808
# Epoch 290, CIFAR-10 Batch 1:  Loss:     1.1065, Train Accuracy:     0.6081, Validation Accuracy: 0.4726
# Epoch 291, CIFAR-10 Batch 1:  Loss:     1.1075, Train Accuracy:     0.6149, Validation Accuracy: 0.4762
# Epoch 292, CIFAR-10 Batch 1:  Loss:     1.0903, Train Accuracy:     0.6284, Validation Accuracy: 0.4704
# Epoch 293, CIFAR-10 Batch 1:  Loss:     1.0927, Train Accuracy:     0.6385, Validation Accuracy: 0.4828
# Epoch 294, CIFAR-10 Batch 1:  Loss:     1.0954, Train Accuracy:     0.6081, Validation Accuracy: 0.4822
# Epoch 295, CIFAR-10 Batch 1:  Loss:     1.0972, Train Accuracy:     0.6081, Validation Accuracy: 0.4794
# Epoch 296, CIFAR-10 Batch 1:  Loss:     1.0915, Train Accuracy:     0.6351, Validation Accuracy: 0.4778
# Epoch 297, CIFAR-10 Batch 1:  Loss:     1.0946, Train Accuracy:     0.6284, Validation Accuracy: 0.4834
# Epoch 298, CIFAR-10 Batch 1:  Loss:     1.0657, Train Accuracy:     0.6318, Validation Accuracy: 0.4720
# Epoch 299, CIFAR-10 Batch 1:  Loss:     1.1013, Train Accuracy:     0.6115, Validation Accuracy: 0.4652
# Epoch 300, CIFAR-10 Batch 1:  Loss:     1.0639, Train Accuracy:     0.6419, Validation Accuracy: 0.4846
# Epoch 301, CIFAR-10 Batch 1:  Loss:     1.0666, Train Accuracy:     0.6318, Validation Accuracy: 0.4778
# Epoch 302, CIFAR-10 Batch 1:  Loss:     1.0827, Train Accuracy:     0.6351, Validation Accuracy: 0.4822
# Epoch 303, CIFAR-10 Batch 1:  Loss:     1.1331, Train Accuracy:     0.6014, Validation Accuracy: 0.4788
# Epoch 304, CIFAR-10 Batch 1:  Loss:     1.0558, Train Accuracy:     0.6419, Validation Accuracy: 0.4740
# Epoch 305, CIFAR-10 Batch 1:  Loss:     1.0515, Train Accuracy:     0.6588, Validation Accuracy: 0.4756
# Epoch 306, CIFAR-10 Batch 1:  Loss:     1.0586, Train Accuracy:     0.6250, Validation Accuracy: 0.4666
# Epoch 307, CIFAR-10 Batch 1:  Loss:     1.0648, Train Accuracy:     0.6351, Validation Accuracy: 0.4804
# Epoch 308, CIFAR-10 Batch 1:  Loss:     1.0791, Train Accuracy:     0.6284, Validation Accuracy: 0.4702
# Epoch 309, CIFAR-10 Batch 1:  Loss:     1.0588, Train Accuracy:     0.6385, Validation Accuracy: 0.4768
# Epoch 310, CIFAR-10 Batch 1:  Loss:     1.0421, Train Accuracy:     0.6351, Validation Accuracy: 0.4798
# Epoch 311, CIFAR-10 Batch 1:  Loss:     1.0309, Train Accuracy:     0.6588, Validation Accuracy: 0.4728
# Epoch 312, CIFAR-10 Batch 1:  Loss:     1.0528, Train Accuracy:     0.6351, Validation Accuracy: 0.4726
# Epoch 313, CIFAR-10 Batch 1:  Loss:     1.0517, Train Accuracy:     0.6419, Validation Accuracy: 0.4770
# Epoch 314, CIFAR-10 Batch 1:  Loss:     1.0368, Train Accuracy:     0.6216, Validation Accuracy: 0.4824
# Epoch 315, CIFAR-10 Batch 1:  Loss:     1.0556, Train Accuracy:     0.6351, Validation Accuracy: 0.4816
# Epoch 316, CIFAR-10 Batch 1:  Loss:     1.0241, Train Accuracy:     0.6419, Validation Accuracy: 0.4876
# Epoch 317, CIFAR-10 Batch 1:  Loss:     1.0405, Train Accuracy:     0.6486, Validation Accuracy: 0.4816
# Epoch 318, CIFAR-10 Batch 1:  Loss:     1.0228, Train Accuracy:     0.6622, Validation Accuracy: 0.4830
# Epoch 319, CIFAR-10 Batch 1:  Loss:     1.0243, Train Accuracy:     0.6655, Validation Accuracy: 0.4860
# Epoch 320, CIFAR-10 Batch 1:  Loss:     1.0411, Train Accuracy:     0.6453, Validation Accuracy: 0.4830
# Epoch 321, CIFAR-10 Batch 1:  Loss:     1.0222, Train Accuracy:     0.6520, Validation Accuracy: 0.4904
# Epoch 322, CIFAR-10 Batch 1:  Loss:     1.0206, Train Accuracy:     0.6486, Validation Accuracy: 0.4880
# Epoch 323, CIFAR-10 Batch 1:  Loss:     1.0130, Train Accuracy:     0.6486, Validation Accuracy: 0.4894
# Epoch 324, CIFAR-10 Batch 1:  Loss:     1.0192, Train Accuracy:     0.6588, Validation Accuracy: 0.4762
# Epoch 325, CIFAR-10 Batch 1:  Loss:     1.0284, Train Accuracy:     0.6520, Validation Accuracy: 0.4794
# Epoch 326, CIFAR-10 Batch 1:  Loss:     1.0184, Train Accuracy:     0.6554, Validation Accuracy: 0.4872
# Epoch 327, CIFAR-10 Batch 1:  Loss:     1.0107, Train Accuracy:     0.6250, Validation Accuracy: 0.4812
# Epoch 328, CIFAR-10 Batch 1:  Loss:     0.9892, Train Accuracy:     0.6757, Validation Accuracy: 0.4880
# Epoch 329, CIFAR-10 Batch 1:  Loss:     1.0107, Train Accuracy:     0.6655, Validation Accuracy: 0.4836
# Epoch 330, CIFAR-10 Batch 1:  Loss:     0.9915, Train Accuracy:     0.6791, Validation Accuracy: 0.4864
# Epoch 331, CIFAR-10 Batch 1:  Loss:     1.0149, Train Accuracy:     0.6453, Validation Accuracy: 0.4694
# Epoch 332, CIFAR-10 Batch 1:  Loss:     1.0162, Train Accuracy:     0.6385, Validation Accuracy: 0.4828
# Epoch 333, CIFAR-10 Batch 1:  Loss:     1.0128, Train Accuracy:     0.6723, Validation Accuracy: 0.4894
# Epoch 334, CIFAR-10 Batch 1:  Loss:     0.9843, Train Accuracy:     0.6622, Validation Accuracy: 0.4830
# Epoch 335, CIFAR-10 Batch 1:  Loss:     0.9850, Train Accuracy:     0.6486, Validation Accuracy: 0.4864
# Epoch 336, CIFAR-10 Batch 1:  Loss:     1.0085, Train Accuracy:     0.6318, Validation Accuracy: 0.4846
# Epoch 337, CIFAR-10 Batch 1:  Loss:     0.9880, Train Accuracy:     0.6655, Validation Accuracy: 0.4938
# Epoch 338, CIFAR-10 Batch 1:  Loss:     0.9811, Train Accuracy:     0.6486, Validation Accuracy: 0.4844
# Epoch 339, CIFAR-10 Batch 1:  Loss:     0.9838, Train Accuracy:     0.6655, Validation Accuracy: 0.4922
# Epoch 340, CIFAR-10 Batch 1:  Loss:     0.9766, Train Accuracy:     0.6689, Validation Accuracy: 0.4950
# Epoch 341, CIFAR-10 Batch 1:  Loss:     0.9717, Train Accuracy:     0.6655, Validation Accuracy: 0.5008
# Epoch 342, CIFAR-10 Batch 1:  Loss:     0.9819, Train Accuracy:     0.6622, Validation Accuracy: 0.4958
# Epoch 343, CIFAR-10 Batch 1:  Loss:     0.9833, Train Accuracy:     0.6622, Validation Accuracy: 0.4940
# Epoch 344, CIFAR-10 Batch 1:  Loss:     0.9722, Train Accuracy:     0.6824, Validation Accuracy: 0.4922
# Epoch 345, CIFAR-10 Batch 1:  Loss:     0.9793, Train Accuracy:     0.6588, Validation Accuracy: 0.4936
# Epoch 346, CIFAR-10 Batch 1:  Loss:     0.9783, Train Accuracy:     0.6486, Validation Accuracy: 0.4900
# Epoch 347, CIFAR-10 Batch 1:  Loss:     1.0090, Train Accuracy:     0.6284, Validation Accuracy: 0.4702
# Epoch 348, CIFAR-10 Batch 1:  Loss:     0.9851, Train Accuracy:     0.6689, Validation Accuracy: 0.4796
# Epoch 349, CIFAR-10 Batch 1:  Loss:     0.9435, Train Accuracy:     0.6959, Validation Accuracy: 0.4864
# Epoch 350, CIFAR-10 Batch 1:  Loss:     0.9544, Train Accuracy:     0.7095, Validation Accuracy: 0.4998
# Epoch 351, CIFAR-10 Batch 1:  Loss:     0.9536, Train Accuracy:     0.6858, Validation Accuracy: 0.4960
# Epoch 352, CIFAR-10 Batch 1:  Loss:     0.9439, Train Accuracy:     0.6791, Validation Accuracy: 0.4978
# Epoch 353, CIFAR-10 Batch 1:  Loss:     0.9371, Train Accuracy:     0.6689, Validation Accuracy: 0.4866
# Epoch 354, CIFAR-10 Batch 1:  Loss:     0.9512, Train Accuracy:     0.6791, Validation Accuracy: 0.4854
# Epoch 355, CIFAR-10 Batch 1:  Loss:     0.9559, Train Accuracy:     0.6723, Validation Accuracy: 0.4950
# Epoch 356, CIFAR-10 Batch 1:  Loss:     0.9915, Train Accuracy:     0.6622, Validation Accuracy: 0.4924
# Epoch 357, CIFAR-10 Batch 1:  Loss:     0.9503, Train Accuracy:     0.6993, Validation Accuracy: 0.4880
# Epoch 358, CIFAR-10 Batch 1:  Loss:     0.9582, Train Accuracy:     0.6892, Validation Accuracy: 0.4920
# Epoch 359, CIFAR-10 Batch 1:  Loss:     0.9796, Train Accuracy:     0.6791, Validation Accuracy: 0.4832
# Epoch 360, CIFAR-10 Batch 1:  Loss:     0.9326, Train Accuracy:     0.7027, Validation Accuracy: 0.4966
# Epoch 361, CIFAR-10 Batch 1:  Loss:     0.9264, Train Accuracy:     0.6993, Validation Accuracy: 0.4974
# Epoch 362, CIFAR-10 Batch 1:  Loss:     0.9085, Train Accuracy:     0.7128, Validation Accuracy: 0.4900
# Epoch 363, CIFAR-10 Batch 1:  Loss:     0.9103, Train Accuracy:     0.7061, Validation Accuracy: 0.4958
# Epoch 364, CIFAR-10 Batch 1:  Loss:     0.8998, Train Accuracy:     0.7230, Validation Accuracy: 0.4952
# Epoch 365, CIFAR-10 Batch 1:  Loss:     0.9215, Train Accuracy:     0.6926, Validation Accuracy: 0.5006
# Epoch 366, CIFAR-10 Batch 1:  Loss:     0.8967, Train Accuracy:     0.6959, Validation Accuracy: 0.5046
# Epoch 367, CIFAR-10 Batch 1:  Loss:     0.9240, Train Accuracy:     0.6926, Validation Accuracy: 0.4972
# Epoch 368, CIFAR-10 Batch 1:  Loss:     0.9063, Train Accuracy:     0.7095, Validation Accuracy: 0.4880
# Epoch 369, CIFAR-10 Batch 1:  Loss:     0.9049, Train Accuracy:     0.7128, Validation Accuracy: 0.4992
# Epoch 370, CIFAR-10 Batch 1:  Loss:     0.9329, Train Accuracy:     0.7027, Validation Accuracy: 0.4856
# Epoch 371, CIFAR-10 Batch 1:  Loss:     0.9436, Train Accuracy:     0.6959, Validation Accuracy: 0.4892
# Epoch 372, CIFAR-10 Batch 1:  Loss:     0.8814, Train Accuracy:     0.7230, Validation Accuracy: 0.4920
# Epoch 373, CIFAR-10 Batch 1:  Loss:     0
# Epoch 37, CIFAR-10 Batch 4:  Loss:     1.5599, Train Accuracy:     0.3818, Validation Accuracy: 0.3770
# Epoch 37, CIFAR-10 Batch 5:  Loss:     1.5845, Train Accuracy:     0.4020, Validation Accuracy: 0.3876
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.6887, Train Accuracy:     0.3074, Validation Accuracy: 0.3818
# Epoch 38, CIFAR-10 Batch 2:  Loss:     1.6224, Train Accuracy:     0.3851, Validation Accuracy: 0.3890
# Epoch 38, CIFAR-10 Batch 3:  Loss:     1.4815, Train Accuracy:     0.4291, Validation Accuracy: 0.3938
# Epoch 38, CIFAR-10 Batch 4:  Loss:     1.5240, Train Accuracy:     0.4054, Validation Accuracy: 0.3794
# Epoch 38, CIFAR-10 Batch 5:  Loss:     1.5763, Train Accuracy:     0.4054, Validation Accuracy: 0.3778
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.6726, Train Accuracy:     0.3108, Validation Accuracy: 0.3860
# Epoch 39, CIFAR-10 Batch 2:  Loss:     1.6275, Train Accuracy:     0.3919, Validation Accuracy: 0.3916
# Epoch 39, CIFAR-10 Batch 3:  Loss:     1.5418, Train Accuracy:     0.4223, Validation Accuracy: 0.3732
# Epoch 39, CIFAR-10 Batch 4:  Loss:     1.5362, Train Accuracy:     0.4020, Validation Accuracy: 0.3862
# Epoch 39, CIFAR-10 Batch 5:  Loss:     1.5567, Train Accuracy:     0.4392, Validation Accuracy: 0.3826
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.6404, Train Accuracy:     0.3378, Validation Accuracy: 0.3836
# Epoch 40, CIFAR-10 Batch 2:  Loss:     1.6102, Train Accuracy:     0.3986, Validation Accuracy: 0.3816
# Epoch 40, CIFAR-10 Batch 3:  Loss:     1.5205, Train Accuracy:     0.4595, Validation Accuracy: 0.3922
# Epoch 40, CIFAR-10 Batch 4:  Loss:     1.5087, Train Accuracy:     0.4493, Validation Accuracy: 0.3838
# Epoch 40, CIFAR-10 Batch 5:  Loss:     1.5593, Train Accuracy:     0.4155, Validation Accuracy: 0.3792
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.6580, Train Accuracy:     0.3311, Validation Accuracy: 0.3894
# Epoch 41, CIFAR-10 Batch 2:  Loss:     1.5952, Train Accuracy:     0.3919, Validation Accuracy: 0.4012
# Epoch 41, CIFAR-10 Batch 3:  Loss:     1.5157, Train Accuracy:     0.4324, Validation Accuracy: 0.3844
# Epoch 41, CIFAR-10 Batch 4:  Loss:     1.5386, Train Accuracy:     0.3919, Validation Accuracy: 0.3858
# Epoch 41, CIFAR-10 Batch 5:  Loss:     1.5577, Train Accuracy:     0.4257, Validation Accuracy: 0.3778
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.6504, Train Accuracy:     0.3311, Validation Accuracy: 0.3878
# Epoch 42, CIFAR-10 Batch 2:  Loss:     1.5798, Train Accuracy:     0.3885, Validation Accuracy: 0.3900
# Epoch 42, CIFAR-10 Batch 3:  Loss:     1.4682, Train Accuracy:     0.4561, Validation Accuracy: 0.3964
# Epoch 42, CIFAR-10 Batch 4:  Loss:     1.5198, Train Accuracy:     0.4257, Validation Accuracy: 0.3850
# Epoch 42, CIFAR-10 Batch 5:  Loss:     1.5299, Train Accuracy:     0.4223, Validation Accuracy: 0.4020
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.6396, Train Accuracy:     0.3581, Validation Accuracy: 0.3960
# Epoch 43, CIFAR-10 Batch 2:  Loss:     1.6087, Train Accuracy:     0.3682, Validation Accuracy: 0.3944
# Epoch 43, CIFAR-10 Batch 3:  Loss:     1.4501, Train Accuracy:     0.4662, Validation Accuracy: 0.3968
# Epoch 43, CIFAR-10 Batch 4:  Loss:     1.5022, Train Accuracy:     0.3986, Validation Accuracy: 0.3944
# Epoch 43, CIFAR-10 Batch 5:  Loss:     1.5430, Train Accuracy:     0.4291, Validation Accuracy: 0.3990
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.6673, Train Accuracy:     0.3514, Validation Accuracy: 0.4008
# Epoch 44, CIFAR-10 Batch 2:  Loss:     1.6088, Train Accuracy:     0.4054, Validation Accuracy: 0.3764
# Epoch 44, CIFAR-10 Batch 3:  Loss:     1.4605, Train Accuracy:     0.4662, Validation Accuracy: 0.4068
# Epoch 44, CIFAR-10 Batch 4:  Loss:     1.5041, Train Accuracy:     0.4392, Validation Accuracy: 0.3934
# Epoch 44, CIFAR-10 Batch 5:  Loss:     1.5413, Train Accuracy:     0.4324, Validation Accuracy: 0.3828
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.6162, Train Accuracy:     0.3649, Validation Accuracy: 0.4032
# Epoch 45, CIFAR-10 Batch 2:  Loss:     1.5678, Train Accuracy:     0.3750, Validation Accuracy: 0.3930
# Epoch 45, CIFAR-10 Batch 3:  Loss:     1.4236, Train Accuracy:     0.4831, Validation Accuracy: 0.4038
# Epoch 45, CIFAR-10 Batch 4:  Loss:     1.4914, Train Accuracy:     0.4189, Validation Accuracy: 0.4042
# Epoch 45, CIFAR-10 Batch 5:  Loss:     1.5279, Train Accuracy:     0.4527, Validation Accuracy: 0.3976
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.6149, Train Accuracy:     0.3378, Validation Accuracy: 0.4012
# Epoch 46, CIFAR-10 Batch 2:  Loss:     1.5744, Train Accuracy:     0.3784, Validation Accuracy: 0.3992
# Epoch 46, CIFAR-10 Batch 3:  Loss:     1.4490, Train Accuracy:     0.4459, Validation Accuracy: 0.4040
# Epoch 46, CIFAR-10 Batch 4:  Loss:     1.5121, Train Accuracy:     0.4088, Validation Accuracy: 0.3932
# Epoch 46, CIFAR-10 Batch 5:  Loss:     1.5108, Train Accuracy:     0.4358, Validation Accuracy: 0.4114
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.5811, Train Accuracy:     0.3547, Validation Accuracy: 0.4086
# Epoch 47, CIFAR-10 Batch 2:  Loss:     1.5548, Train Accuracy:     0.4020, Validation Accuracy: 0.4074
# Epoch 47, CIFAR-10 Batch 3:  Loss:     1.4131, Train Accuracy:     0.4595, Validation Accuracy: 0.4096
# Epoch 47, CIFAR-10 Batch 4:  Loss:     1.4776, Train Accuracy:     0.4527, Validation Accuracy: 0.4106
# Epoch 47, CIFAR-10 Batch 5:  Loss:     1.5303, Train Accuracy:     0.4257, Validation Accuracy: 0.4136
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.5809, Train Accuracy:     0.3615, Validation Accuracy: 0.4154
# Epoch 48, CIFAR-10 Batch 2:  Loss:     1.5443, Train Accuracy:     0.3885, Validation Accuracy: 0.4156
# Epoch 48, CIFAR-10 Batch 3:  Loss:     1.4116, Train Accuracy:     0.4527, Validation Accuracy: 0.4158
# Epoch 48, CIFAR-10 Batch 4:  Loss:     1.4599, Train Accuracy:     0.4291, Validation Accuracy: 0.4176
# Epoch 48, CIFAR-10 Batch 5:  Loss:     1.4880, Train Accuracy:     0.4595, Validation Accuracy: 0.4220
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.6225, Train Accuracy:     0.3547, Validation Accuracy: 0.3958
# Epoch 49, CIFAR-10 Batch 2:  Loss:     1.5341, Train Accuracy:     0.3953, Validation Accuracy: 0.4184
# Epoch 49, CIFAR-10 Batch 3:  Loss:     1.5144, Train Accuracy:     0.4426, Validation Accuracy: 0.4080
# Epoch 49, CIFAR-10 Batch 4:  Loss:     1.4490, Train Accuracy:     0.4493, Validation Accuracy: 0.4274
# Epoch 49, CIFAR-10 Batch 5:  Loss:     1.4870, Train Accuracy:     0.4392, Validation Accuracy: 0.4180
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.5696, Train Accuracy:     0.3682, Validation Accuracy: 0.4180
# Epoch 50, CIFAR-10 Batch 2:  Loss:     1.5268, Train Accuracy:     0.4020, Validation Accuracy: 0.4224
# Epoch 50, CIFAR-10 Batch 3:  Loss:     1.4393, Train Accuracy:     0.4932, Validation Accuracy: 0.4150
# Epoch 50, CIFAR-10 Batch 4:  Loss:     1.4395, Train Accuracy:     0.4595, Validation Accuracy: 0.4208
# Epoch 50, CIFAR-10 Batch 5:  Loss:     1.4770, Train Accuracy:     0.4628, Validation Accuracy: 0.4254
# Epoch 51, CIFAR-10 Batch 1:  Loss:     1.5722, Train Accuracy:     0.3818, Validation Accuracy: 0.4258
# Epoch 51, CIFAR-10 Batch 2:  Loss:     1.4901, Train Accuracy:     0.4189, Validation Accuracy: 0.4232
# Epoch 51, CIFAR-10 Batch 3:  Loss:     1.4216, Train Accuracy:     0.4696, Validation Accuracy: 0.4164
# Epoch 51, CIFAR-10 Batch 4:  Loss:     1.4395, Train Accuracy:     0.4628, Validation Accuracy: 0.4206
# Epoch 51, CIFAR-10 Batch 5:  Loss:     1.5005, Train Accuracy:     0.4223, Validation Accuracy: 0.4264
# Epoch 52, CIFAR-10 Batch 1:  Loss:     1.5807, Train Accuracy:     0.3716, Validation Accuracy: 0.4180
# Epoch 52, CIFAR-10 Batch 2:  Loss:     1.5126, Train Accuracy:     0.4223, Validation Accuracy: 0.4200
# Epoch 52, CIFAR-10 Batch 3:  Loss:     1.3781, Train Accuracy:     0.4932, Validation Accuracy: 0.4312
# Epoch 52, CIFAR-10 Batch 4:  Loss:     1.4307, Train Accuracy:     0.4628, Validation Accuracy: 0.4300
# Epoch 52, CIFAR-10 Batch 5:  Loss:     1.4748, Train Accuracy:     0.4865, Validation Accuracy: 0.4286
# Epoch 53, CIFAR-10 Batch 1:  Loss:     1.5837, Train Accuracy:     0.3953, Validation Accuracy: 0.4254
# Epoch 53, CIFAR-10 Batch 2:  Loss:     1.5052, Train Accuracy:     0.4291, Validation Accuracy: 0.4260
# Epoch 53, CIFAR-10 Batch 3:  Loss:     1.3903, Train Accuracy:     0.5068, Validation Accuracy: 0.4216
# Epoch 53, CIFAR-10 Batch 4:  Loss:     1.4207, Train Accuracy:     0.4493, Validation Accuracy: 0.4242
# Epoch 53, CIFAR-10 Batch 5:  Loss:     1.4768, Train Accuracy:     0.4797, Validation Accuracy: 0.4184
# Epoch 54, CIFAR-10 Batch 1:  Loss:     1.5656, Train Accuracy:     0.3547, Validation Accuracy: 0.4348
# Epoch 54, CIFAR-10 Batch 2:  Loss:     1.5139, Train Accuracy:     0.4426, Validation Accuracy: 0.4206
# Epoch 54, CIFAR-10 Batch 3:  Loss:     1.3786, Train Accuracy:     0.5101, Validation Accuracy: 0.4282
# Epoch 54, CIFAR-10 Batch 4:  Loss:     1.4420, Train Accuracy:     0.4561, Validation Accuracy: 0.4308
# Epoch 54, CIFAR-10 Batch 5:  Loss:     1.4605, Train Accuracy:     0.4324, Validation Accuracy: 0.4364
# Epoch 55, CIFAR-10 Batch 1:  Loss:     1.5254, Train Accuracy:     0.4020, Validation Accuracy: 0.4332
# Epoch 55, CIFAR-10 Batch 2:  Loss:     1.4935, Train Accuracy:     0.4189, Validation Accuracy: 0.4318
# Epoch 55, CIFAR-10 Batch 3:  Loss:     1.3561, Train Accuracy:     0.5068, Validation Accuracy: 0.4390
# Epoch 55, CIFAR-10 Batch 4:  Loss:     1.4181, Train Accuracy:     0.4561, Validation Accuracy: 0.4214
# Epoch 55, CIFAR-10 Batch 5:  Loss:     1.4376, Train Accuracy:     0.4865, Validation Accuracy: 0.4388
# Epoch 56, CIFAR-10 Batch 1:  Loss:     1.5207, Train Accuracy:     0.4088, Validation Accuracy: 0.4440
# Epoch 56, CIFAR-10 Batch 2:  Loss:     1.4795, Train Accuracy:     0.4764, Validation Accuracy: 0.4272
# Epoch 56, CIFAR-10 Batch 3:  Loss:     1.3313, Train Accuracy:     0.5101, Validation Accuracy: 0.4392
# Epoch 56, CIFAR-10 Batch 4:  Loss:     1.4082, Train Accuracy:     0.4662, Validation Accuracy: 0.4394
# Epoch 56, CIFAR-10 Batch 5:  Loss:     1.4580, Train Accuracy:     0.4831, Validation Accuracy: 0.4526
# Epoch 57, CIFAR-10 Batch 1:  Loss:     1.5376, Train Accuracy:     0.3885, Validation Accuracy: 0.4418
# Epoch 57, CIFAR-10 Batch 2:  Loss:     1.4863, Train Accuracy:     0.4527, Validation Accuracy: 0.4358
# Epoch 57, CIFAR-10 Batch 3:  Loss:     1.3274, Train Accuracy:     0.5304, Validation Accuracy: 0.4366
# Epoch 57, CIFAR-10 Batch 4:  Loss:     1.3823, Train Accuracy:     0.5304, Validation Accuracy: 0.4444
# Epoch 57, CIFAR-10 Batch 5:  Loss:     1.4560, Train Accuracy:     0.4561, Validation Accuracy: 0.4308
# Epoch 58, CIFAR-10 Batch 1:  Loss:     1.5516, Train Accuracy:     0.3682, Validation Accuracy: 0.4338
# Epoch 58, CIFAR-10 Batch 2:  Loss:     1.4946, Train Accuracy:     0.4257, Validation Accuracy: 0.4380
# Epoch 58, CIFAR-10 Batch 3:  Loss:     1.3093, Train Accuracy:     0.5338, Validation Accuracy: 0.4422
# Epoch 58, CIFAR-10 Batch 4:  Loss:     1.3830, Train Accuracy:     0.4932, Validation Accuracy: 0.4482
# Epoch 58, CIFAR-10 Batch 5:  Loss:     1.4408, Train Accuracy:     0.4797, Validation Accuracy: 0.4366
# Epoch 59, CIFAR-10 Batch 1:  Loss:     1.5196, Train Accuracy:     0.4088, Validation Accuracy: 0.4408
# Epoch 59, CIFAR-10 Batch 2:  Loss:     1.4518, Train Accuracy:     0.4426, Validation Accuracy: 0.4392
# Epoch 59, CIFAR-10 Batch 3:  Loss:     1.3112, Train Accuracy:     0.5405, Validation Accuracy: 0.4518
# Epoch 59, CIFAR-10 Batch 4:  Loss:     1.3760, Train Accuracy:     0.4628, Validation Accuracy: 0.4450
# Epoch 59, CIFAR-10 Batch 5:  Loss:     1.4204, Train Accuracy:     0.4797, Validation Accuracy: 0.4456
# Epoch 60, CIFAR-10 Batch 1:  Loss:     1.4833, Train Accuracy:     0.4054, Validation Accuracy: 0.4500
# Epoch 60, CIFAR-10 Batch 2:  Loss:     1.4157, Train Accuracy:     0.4459, Validation Accuracy: 0.4430
# Epoch 60, CIFAR-10 Batch 3:  Loss:     1.2935, Train Accuracy:     0.5439, Validation Accuracy: 0.4476
# Epoch 60, CIFAR-10 Batch 4:  Loss:     1.3820, Train Accuracy:     0.4966, Validation Accuracy: 0.4478
# Epoch 60, CIFAR-10 Batch 5:  Loss:     1.4426, Train Accuracy:     0.4459, Validation Accuracy: 0.4416
# Epoch 61, CIFAR-10 Batch 1:  Loss:     1.5117, Train Accuracy:     0.4189, Validation Accuracy: 0.4410
# Epoch 61, CIFAR-10 Batch 2:  Loss:     1.4537, Train Accuracy:     0.4223, Validation Accuracy: 0.4352
# Epoch 61, CIFAR-10 Batch 3:  Loss:     1.2742, Train Accuracy:     0.5608, Validation Accuracy: 0.4542
# Epoch 61, CIFAR-10 Batch 4:  Loss:     1.3397, Train Accuracy:     0.5135, Validation Accuracy: 0.4552
# Epoch 61, CIFAR-10 Batch 5:  Loss:     1.4045, Train Accuracy:     0.4831, Validation Accuracy: 0.4514
# Epoch 62, CIFAR-10 Batch 1:  Loss:     1.4935, Train Accuracy:     0.4054, Validation Accuracy: 0.4416
# Epoch 62, CIFAR-10 Batch 2:  Loss:     1.4248, Train Accuracy:     0.4459, Validation Accuracy: 0.4466
# Epoch 62, CIFAR-10 Batch 3:  Loss:     1.3090, Train Accuracy:     0.5135, Validation Accuracy: 0.4408
# Epoch 62, CIFAR-10 Batch 4:  Loss:     1.3437, Train Accuracy:     0.4932, Validation Accuracy: 0.4602
# Epoch 62, CIFAR-10 Batch 5:  Loss:     1.3999, Train Accuracy:     0.4865, Validation Accuracy: 0.4530
# Epoch 63, CIFAR-10 Batch 1:  Loss:     1.4845, Train Accuracy:     0.4122, Validation Accuracy: 0.4490
# Epoch 63, CIFAR-10 Batch 2:  Loss:     1.4095, Train Accuracy:     0.4797, Validation Accuracy: 0.4598
# Epoch 63, CIFAR-10 Batch 3:  Loss:     1.2713, Train Accuracy:     0.5473, Validation Accuracy: 0.4492
# Epoch 63, CIFAR-10 Batch 4:  Loss:     1.3298, Train Accuracy:     0.4696, Validation Accuracy: 0.4480
# Epoch 63, CIFAR-10 Batch 5:  Loss:     1.3708, Train Accuracy:     0.4899, Validation Accuracy: 0.4558
# Epoch 64, CIFAR-10 Batch 1:  Loss:     1.4725, Train Accuracy:     0.4291, Validation Accuracy: 0.4562
# Epoch 64, CIFAR-10 Batch 2:  Loss:     1.3888, Train Accuracy:     0.4899, Validation Accuracy: 0.4606
# Epoch 64, CIFAR-10 Batch 3:  Loss:     1.2641, Train Accuracy:     0.5676, Validation Accuracy: 0.4604
# Epoch 64, CIFAR-10 Batch 4:  Loss:     1.3541, Train Accuracy:     0.5000, Validation Accuracy: 0.4572
# Epoch 64, CIFAR-10 Batch 5:  Loss:     1.3798, Train Accuracy:     0.4865, Validation Accuracy: 0.4544
# Epoch 65, CIFAR-10 Batch 1:  Loss:     1.4830, Train Accuracy:     0.4189, Validation Accuracy: 0.4534
# Epoch 65, CIFAR-10 Batch 2:  Loss:     1.3909, Train Accuracy:     0.4764, Validation Accuracy: 0.4592
# Epoch 65, CIFAR-10 Batch 3:  Loss:     1.2603, Train Accuracy:     0.5709, Validation Accuracy: 0.4660
# Epoch 65, CIFAR-10 Batch 4:  Loss:     1.3680, Train Accuracy:     0.4493, Validation Accuracy: 0.4566
# Epoch 65, CIFAR-10 Batch 5:  Loss:     1.3833, Train Accuracy:     0.5236, Validation Accuracy: 0.4572
# Epoch 66, CIFAR-10 Batch 1:  Loss:     1.4818, Train Accuracy:     0.4223, Validation Accuracy: 0.4550
# Epoch 66, CIFAR-10 Batch 2:  Loss:     1.3969, Train Accuracy:     0.5068, Validation Accuracy: 0.4504
# Epoch 66, CIFAR-10 Batch 3:  Loss:     1.2734, Train Accuracy:     0.5541, Validation Accuracy: 0.4570
# Epoch 66, CIFAR-10 Batch 4:  Loss:     1.3205, Train Accuracy:     0.4730, Validation Accuracy: 0.4638
# Epoch 66, CIFAR-10 Batch 5:  Loss:     1.3728, Train Accuracy:     0.4966, Validation Accuracy: 0.4560
# Epoch 67, CIFAR-10 Batch 1:  Loss:     1.4734, Train Accuracy:     0.4054, Validation Accuracy: 0.4696
# Epoch 67, CIFAR-10 Batch 2:  Loss:     1.3965, Train Accuracy:     0.4899, Validation Accuracy: 0.4618
# Epoch 67, CIFAR-10 Batch 3:  Loss:     1.2621, Train Accuracy:     0.5574, Validation Accuracy: 0.4596
# Epoch 67, CIFAR-10 Batch 4:  Loss:     1.3202, Train Accuracy:     0.4730, Validation Accuracy: 0.4664
# Epoch 67, CIFAR-10 Batch 5:  Loss:     1.3582, Train Accuracy:     0.5304, Validation Accuracy: 0.4750
# Epoch 68, CIFAR-10 Batch 1:  Loss:     1.4965, Train Accuracy:     0.4155, Validation Accuracy: 0.4498
# Epoch 68, CIFAR-10 Batch 2:  Loss:     1.3536, Train Accuracy:     0.5000, Validation Accuracy: 0.4636
# Epoch 68, CIFAR-10 Batch 3:  Loss:     1.2273, Train Accuracy:     0.5676, Validation Accuracy: 0.4706
# Epoch 68, CIFAR-10 Batch 4:  Loss:     1.3084, Train Accuracy:     0.5203, Validation Accuracy: 0.4708
# Epoch 68, CIFAR-10 Batch 5:  Loss:     1.3389, Train Accuracy:     0.5270, Validation Accuracy: 0.4590
# Epoch 69, CIFAR-10 Batch 1:  Loss:     1.4525, Train Accuracy:     0.4459, Validation Accuracy: 0.4590
# Epoch 69, CIFAR-10 Batch 2:  Loss:     1.3865, Train Accuracy:     0.5169, Validation Accuracy: 0.4616
# Epoch 69, CIFAR-10 Batch 3:  Loss:     1.2292, Train Accuracy:     0.5811, Validation Accuracy: 0.4762
# Epoch 69, CIFAR-10 Batch 4:  Loss:     1.3300, Train Accuracy:     0.4730, Validation Accuracy: 0.4604
# Epoch 69, CIFAR-10 Batch 5:  Loss:     1.3265, Train Accuracy:     0.5338, Validation Accuracy: 0.4672
# Epoch 70, CIFAR-10 Batch 1:  Loss:     1.4802, Train Accuracy:     0.4122, Validation Accuracy: 0.4626
# Epoch 70, CIFAR-10 Batch 2:  Loss:     1.3729, Train Accuracy:     0.4831, Validation Accuracy: 0.4574
# Epoch 70, CIFAR-10 Batch 3:  Loss:     1.2003, Train Accuracy:     0.5743, Validation Accuracy: 0.4678
# Epoch 70, CIFAR-10 Batch 4:  Loss:     1.3266, Train Accuracy:     0.5135, Validation Accuracy: 0.4740
# Epoch 70, CIFAR-10 Batch 5:  Loss:     1.3284, Train Accuracy:     0.5338, Validation Accuracy: 0.4788
# Epoch 71, CIFAR-10 Batch 1:  Loss:     1.4725, Train Accuracy:     0.4426, Validation Accuracy: 0.4716
# Epoch 71, CIFAR-10 Batch 2:  Loss:     1.3724, Train Accuracy:     0.5068, Validation Accuracy: 0.4542
# Epoch 71, CIFAR-10 Batch 3:  Loss:     1.1932, Train Accuracy:     0.5946, Validation Accuracy: 0.4766
# Epoch 71, CIFAR-10 Batch 4:  Loss:     1.2934, Train Accuracy:     0.5101, Validation Accuracy: 0.4764
# Epoch 71, CIFAR-10 Batch 5:  Loss:     1.3049, Train Accuracy:     0.5372, Validation Accuracy: 0.4738
# Epoch 72, CIFAR-10 Batch 1:  Loss:     1.4369, Train Accuracy:     0.4797, Validation Accuracy: 0.4670
# Epoch 72, CIFAR-10 Batch 2:  Loss:     1.3708, Train Accuracy:     0.4865, Validation Accuracy: 0.4640
# Epoch 72, CIFAR-10 Batch 3:  Loss:     1.1971, Train Accuracy:     0.5845, Validation Accuracy: 0.4770
# Epoch 72, CIFAR-10 Batch 4:  Loss:     1.2946, Train Accuracy:     0.5101, Validation Accuracy: 0.4724
# Epoch 72, CIFAR-10 Batch 5:  Loss:     1.3433, Train Accuracy:     0.5135, Validation Accuracy: 0.4716
# Epoch 73, CIFAR-10 Batch 1:  Loss:     1.4327, Train Accuracy:     0.4223, Validation Accuracy: 0.4730
# Epoch 73, CIFAR-10 Batch 2:  Loss:     1.3349, Train Accuracy:     0.4899, Validation Accuracy: 0.4780
# Epoch 73, CIFAR-10 Batch 3:  Loss:     1.2078, Train Accuracy:     0.5642, Validation Accuracy: 0.4742
# Epoch 73, CIFAR-10 Batch 4:  Loss:     1.2710, Train Accuracy:     0.5203, Validation Accuracy: 0.4802
# Epoch 73, CIFAR-10 Batch 5:  Loss:     1.2951, Train Accuracy:     0.5304, Validation Accuracy: 0.4774
# Epoch 74, CIFAR-10 Batch 1:  Loss:     1.4354, Train Accuracy:     0.4459, Validation Accuracy: 0.4744
# Epoch 74, CIFAR-10 Batch 2:  Loss:     1.3439, Train Accuracy:     0.4899, Validation Accuracy: 0.4696
# Epoch 74, CIFAR-10 Batch 3:  Loss:     1.1987, Train Accuracy:     0.5777, Validation Accuracy: 0.4696
# Epoch 74, CIFAR-10 Batch 4:  Loss:     1.3036, Train Accuracy:     0.5236, Validation Accuracy: 0.4654
# Epoch 74, CIFAR-10 Batch 5:  Loss:     1.2922, Train Accuracy:     0.5203, Validation Accuracy: 0.4900
# Epoch 75, CIFAR-10 Batch 1:  Loss:     1.4064, Train Accuracy:     0.4595, Validation Accuracy: 0.4878
# Epoch 75, CIFAR-10 Batch 2:  Loss:     1.3162, Train Accuracy:     0.5135, Validation Accuracy: 0.4858
# Epoch 75, CIFAR-10 Batch 3:  Loss:     1.2244, Train Accuracy:     0.5473, Validation Accuracy: 0.4796
# Epoch 75, CIFAR-10 Batch 4:  Loss:     1.2688, Train Accuracy:     0.5236, Validation Accuracy: 0.4866
# Epoch 75, CIFAR-10 Batch 5:  Loss:     1.3089, Train Accuracy:     0.5372, Validation Accuracy: 0.4660
# Epoch 76, CIFAR-10 Batch 1:  Loss:     1.4801, Train Accuracy:     0.4324, Validation Accuracy: 0.4668
# Epoch 76, CIFAR-10 Batch 2:  Loss:     1.3193, Train Accuracy:     0.5270, Validation Accuracy: 0.4722
# Epoch 76, CIFAR-10 Batch 3:  Loss:     1.2324, Train Accuracy:     0.5169, Validation Accuracy: 0.4720
# Epoch 76, CIFAR-10 Batch 4:  Loss:     1.2880, Train Accuracy:     0.5439, Validation Accuracy: 0.4726
# Epoch 76, CIFAR-10 Batch 5:  Loss:     1.2769, Train Accuracy:     0.5608, Validation Accuracy: 0.4836
# Epoch 77, CIFAR-10 Batch 1:  Loss:     1.4326, Train Accuracy:     0.4595, Validation Accuracy: 0.4780
# Epoch 77, CIFAR-10 Batch 2:  Loss:     1.3068, Train Accuracy:     0.5304, Validation Accuracy: 0.4880
# Epoch 77, CIFAR-10 Batch 3:  Loss:     1.1618, Train Accuracy:     0.5946, Validation Accuracy: 0.4902
# Epoch 77, CIFAR-10 Batch 4:  Loss:     1.2709, Train Accuracy:     0.5135, Validation Accuracy: 0.4842
# Epoch 77, CIFAR-10 Batch 5:  Loss:     1.2947, Train Accuracy:     0.5372, Validation Accuracy: 0.4752
# Epoch 78, CIFAR-10 Batch 1:  Loss:     1.4407, Train Accuracy:     0.4324, Validation Accuracy: 0.4876
# Epoch 78, CIFAR-10 Batch 2:  Loss:     1.3110, Train Accuracy:     0.5101, Validation Accuracy: 0.4914
# Epoch 78, CIFAR-10 Batch 3:  Loss:     1.1827, Train Accuracy:     0.5709, Validation Accuracy: 0.4824
# Epoch 78, CIFAR-10 Batch 4:  Loss:     1.2592, Train Accuracy:     0.5203, Validation Accuracy: 0.4810
# Epoch 78, CIFAR-10 Batch 5:  Loss:     1.2559, Train Accuracy:     0.5608, Validation Accuracy: 0.4860
# Epoch 79, CIFAR-10 Batch 1:  Loss:     1.4190, Train Accuracy:     0.4392, Validation Accuracy: 0.4816
# Epoch 79, CIFAR-10 Batch 2:  Loss:     1.2882, Train Accuracy:     0.5101, Validation Accuracy: 0.4862
# Epoch 79, CIFAR-10 Batch 3:  Loss:     1.1931, Train Accuracy:     0.5541, Validation Accuracy: 0.4826
# Epoch 79, CIFAR-10 Batch 4:  Loss:     1.2479, Train Accuracy:     0.5372, Validation Accuracy: 0.4920
# Epoch 79, CIFAR-10 Batch 5:  Loss:     1.2817, Train Accuracy:     0.5473, Validation Accuracy: 0.4938
# Epoch 80, CIFAR-10 Batch 1:  Loss:     1.3953, Train Accuracy:     0.4797, Validation Accuracy: 0.4832
# Epoch 80, CIFAR-10 Batch 2:  Loss:     1.2791, Train Accuracy:     0.5135, Validation Accuracy: 0.4818
# Epoch 80, CIFAR-10 Batch 3:  Loss:     1.1722, Train Accuracy:     0.5845, Validation Accuracy: 0.4828
# Epoch 80, CIFAR-10 Batch 4:  Loss:     1.2435, Train Accuracy:     0.5270, Validation Accuracy: 0.4814
# Epoch 80, CIFAR-10 Batch 5:  Loss:     1.2491, Train Accuracy:     0.5845, Validation Accuracy: 0.4910
# Epoch 81, CIFAR-10 Batch 1:  Loss:     1.3997, Train Accuracy:     0.4797, Validation Accuracy: 0.4860
# Epoch 81, CIFAR-10 Batch 2:  Loss:     1.2733, Train Accuracy:     0.5203, Validation Accuracy: 0.4846
# Epoch 81, CIFAR-10 Batch 3:  Loss:     1.1561, Train Accuracy:     0.5709, Validation Accuracy: 0.4934
# Epoch 81, CIFAR-10 Batch 4:  Loss:     1.2540, Train Accuracy:     0.5236, Validation Accuracy: 0.4908
# Epoch 81, CIFAR-10 Batch 5:  Loss:     1.2321, Train Accuracy:     0.5608, Validation Accuracy: 0.4904
# Epoch 82, CIFAR-10 Batch 1:  Loss:     1.4042, Train Accuracy:     0.4764, Validation Accuracy: 0.4858
# Epoch 82, CIFAR-10 Batch 2:  Loss:     1.2698, Train Accuracy:     0.5203, Validation Accuracy: 0.4872
# Epoch 82, CIFAR-10 Batch 3:  Loss:     1.1442, Train Accuracy:     0.5946, Validation Accuracy: 0.4962
# Epoch 82, CIFAR-10 Batch 4:  Loss:     1.2533, Train Accuracy:     0.5034, Validation Accuracy: 0.4948
# Epoch 82, CIFAR-10 Batch 5:  Loss:     1.2262, Train Accuracy:     0.5811, Validation Accuracy: 0.4968
# Epoch 83, CIFAR-10 Batch 1:  Loss:     1.4257, Train Accuracy:     0.4291, Validation Accuracy: 0.4742
# Epoch 83, CIFAR-10 Batch 2:  Loss:     1.2688, Train Accuracy:     0.5169, Validation Accuracy: 0.4918
# Epoch 83, CIFAR-10 Batch 3:  Loss:     1.1791, Train Accuracy:     0.5912, Validation Accuracy: 0.4802
# Epoch 83, CIFAR-10 Batch 4:  Loss:     1.2523, Train Accuracy:     0.5574, Validation Accuracy: 0.4946
# Epoch 83, CIFAR-10 Batch 5:  Loss:     1.2358, Train Accuracy:     0.5743, Validation Accuracy: 0.4926
# Epoch 84, CIFAR-10 Batch 1:  Loss:     1.3960, Train Accuracy:     0.4595, Validation Accuracy: 0.4862
# Epoch 84, CIFAR-10 Batch 2:  Loss:     1.2595, Train Accuracy:     0.5338, Validation Accuracy: 0.4852
# Epoch 84, CIFAR-10 Batch 3:  Loss:     1.1334, Train Accuracy:     0.5912, Validation Accuracy: 0.4908
# Epoch 84, CIFAR-10 Batch 4:  Loss:     1.2427, Train Accuracy:     0.5439, Validation Accuracy: 0.4876
# Epoch 84, CIFAR-10 Batch 5:  Loss:     1.2121, Train Accuracy:     0.5676, Validation Accuracy: 0.5004
# Epoch 85, CIFAR-10 Batch 1:  Loss:     1.3736, Train Accuracy:     0.4730, Validation Accuracy: 0.4922
# Epoch 85, CIFAR-10 Batch 2:  Loss:     1.2617, Train Accuracy:     0.5372, Validation Accuracy: 0.4888
# Epoch 85, CIFAR-10 Batch 3:  Loss:     1.1473, Train Accuracy:     0.5946, Validation Accuracy: 0.4942
# Epoch 85, CIFAR-10 Batch 4:  Loss:     1.2506, Train Accuracy:     0.5169, Validation Accuracy: 0.4918
# Epoch 85, CIFAR-10 Batch 5:  Loss:     1.2189, Train Accuracy:     0.5777, Validation Accuracy: 0.4924
# Epoch 86, CIFAR-10 Batch 1:  Loss:     1.3945, Train Accuracy:     0.4459, Validation Accuracy: 0.4860
# Epoch 86, CIFAR-10 Batch 2:  Loss:     1.2729, Train Accuracy:     0.5372, Validation Accuracy: 0.4792
# Epoch 86, CIFAR-10 Batch 3:  Loss:     1.1770, Train Accuracy:     0.6081, Validation Accuracy: 0.4880
# Epoch 86, CIFAR-10 Batch 4:  Loss:     1.2262, Train Accuracy:     0.5473, Validation Accuracy: 0.4974
# Epoch 86, CIFAR-10 Batch 5:  Loss:     1.2306, Train Accuracy:     0.5608, Validation Accuracy: 0.4890
# Epoch 87, CIFAR-10 Batch 1:  Loss:     1.3655, Train Accuracy:     0.4899, Validation Accuracy: 0.4988
# Epoch 87, CIFAR-10 Batch 2:  Loss:     1.2609, Train Accuracy:     0.5236, Validation Accuracy: 0.4972
# Epoch 87, CIFAR-10 Batch 3:  Loss:     1.1351, Train Accuracy:     0.6047, Validation Accuracy: 0.5014
# Epoch 87, CIFAR-10 Batch 4:  Loss:     1.2339, Train Accuracy:     0.5541, Validation Accuracy: 0.4916
# Epoch 87, CIFAR-10 Batch 5:  Loss:     1.2170, Train Accuracy:     0.5777, Validation Accuracy: 0.4994
# Epoch 88, CIFAR-10 Batch 1:  Loss:     1.3776, Train Accuracy:     0.4595, Validation Accuracy: 0.4822
# Epoch 88, CIFAR-10 Batch 2:  Loss:     1.2687, Train Accuracy:     0.5203, Validation Accuracy: 0.4938
# Epoch 88, CIFAR-10 Batch 3:  Loss:     1.1432, Train Accuracy:     0.6115, Validation Accuracy: 0.4876
# Epoch 88, CIFAR-10 Batch 4:  Loss:     1.2323, Train Accuracy:     0.5338, Validation Accuracy: 0.4906
# Epoch 88, CIFAR-10 Batch 5:  Loss:     1.1971, Train Accuracy:     0.5912, Validation Accuracy: 0.4958
# Epoch 89, CIFAR-10 Batch 1:  Loss:     1.3608, Train Accuracy:     0.4831, Validation Accuracy: 0.4948
# Epoch 89, CIFAR-10 Batch 2:  Loss:     1.2583, Train Accuracy:     0.5270, Validation Accuracy: 0.4998
# Epoch 89, CIFAR-10 Batch 3:  Loss:     1.1596, Train Accuracy:     0.6419, Validation Accuracy: 0.4982
# Epoch 89, CIFAR-10 Batch 4:  Loss:     1.2326, Train Accuracy:     0.5372, Validation Accuracy: 0.4904
# Epoch 89, CIFAR-10 Batch 5:  Loss:     1.2313, Train Accuracy:     0.5574, Validation Accuracy: 0.4950
# Epoch 90, CIFAR-10 Batch 1:  Loss:     1.3586, Train Accuracy:     0.4662, Validation Accuracy: 0.4920
# Epoch 90, CIFAR-10 Batch 2:  Loss:     1.2582, Train Accuracy:     0.5473, Validation Accuracy: 0.5020
# Epoch 90, CIFAR-10 Batch 3:  Loss:     1.1241, Train Accuracy:     0.6216, Validation Accuracy: 0.4970
# Epoch 90, CIFAR-10 Batch 4:  Loss:     1.2380, Train Accuracy:     0.5642, Validation Accuracy: 0.4960
# Epoch 90, CIFAR-10 Batch 5:  Loss:     1.2192, Train Accuracy:     0.5676, Validation Accuracy: 0.4926
# Epoch 91, CIFAR-10 Batch 1:  Loss:     1.3694, Train Accuracy:     0.4628, Validation Accuracy: 0.4924
# Epoch 91, CIFAR-10 Batch 2:  Loss:     1.2353, Train Accuracy:     0.5642, Validation Accuracy: 0.4992
# Epoch 91, CIFAR-10 Batch 3:  Loss:     1.1324, Train Accuracy:     0.5777, Validation Accuracy: 0.4950
# Epoch 91, CIFAR-10 Batch 4:  Loss:     1.2102, Train Accuracy:     0.5541, Validation Accuracy: 0.5014
# Epoch 91, CIFAR-10 Batch 5:  Loss:     1.2030, Train Accuracy:     0.5541, Validation Accuracy: 0.4996
# Epoch 92, CIFAR-10 Batch 1:  Loss:     1.3422, Train Accuracy:     0.5000, Validation Accuracy: 0.5054
# Epoch 92, CIFAR-10 Batch 2:  Loss:     1.2298, Train Accuracy:     0.5372, Validation Accuracy: 0.5064
# Epoch 92, CIFAR-10 Batch 3:  Loss:     1.1123, Train Accuracy:     0.5845, Validation Accuracy: 0.5036
# Epoch 92, CIFAR-10 Batch 4:  Loss:     1.1944, Train Accuracy:     0.5574, Validation Accuracy: 0.5024
# Epoch 92, CIFAR-10 Batch 5:  Loss:     1.2206, Train Accuracy:     0.5946, Validation Accuracy: 0.5084
# Epoch 93, CIFAR-10 Batch 1:  Loss:     1.3562, Train Accuracy:     0.4899, Validation Accuracy: 0.4974
# Epoch 93, CIFAR-10 Batch 2:  Loss:     1.2351, Train Accuracy:     0.5642, Validation Accuracy: 0.4976
# Epoch 93, CIFAR-10 Batch 3:  Loss:     1.0835, Train Accuracy:     0.6115, Validation Accuracy: 0.4998
# Epoch 93, CIFAR-10 Batch 4:  Loss:     1.1789, Train Accuracy:     0.5574, Validation Accuracy: 0.4978
# Epoch 93, CIFAR-10 Batch 5:  Loss:     1.1946, Train Accuracy:     0.5642, Validation Accuracy: 0.4968
# ...
# Epoch 370, CIFAR-10 Batch 3:  Loss:     0.5171, Train Accuracy:     0.8514, Validation Accuracy: 0.6092
# Epoch 370, CIFAR-10 Batch 4:  Loss:     0.5641, Train Accuracy:     0.8243, Validation Accuracy: 0.6116
# Epoch 370, CIFAR-10 Batch 5:  Loss:     0.6052, Train Accuracy:     0.7703, Validation Accuracy: 0.6088
# Epoch 371, CIFAR-10 Batch 1:  Loss:     0.6596, Train Accuracy:     0.7432, Validation Accuracy: 0.6166
# Epoch 371, CIFAR-10 Batch 2:  Loss:     0.5796, Train Accuracy:     0.8176, Validation Accuracy: 0.6066
# Epoch 371, CIFAR-10 Batch 3:  Loss:     0.5133, Train Accuracy:     0.8547, Validation Accuracy: 0.6114
# Epoch 371, CIFAR-10 Batch 4:  Loss:     0.6093, Train Accuracy:     0.7939, Validation Accuracy: 0.6000
# Epoch 371, CIFAR-10 Batch 5:  Loss:     0.6245, Train Accuracy:     0.7770, Validation Accuracy: 0.6066
# Epoch 372, CIFAR-10 Batch 1:  Loss:     0.6950, Train Accuracy:     0.7466, Validation Accuracy: 0.6124
# Epoch 372, CIFAR-10 Batch 2:  Loss:     0.5588, Train Accuracy:     0.8142, Validation Accuracy: 0.6090
# Epoch 372, CIFAR-10 Batch 3:  Loss:     0.5134, Train Accuracy:     0.8446, Validation Accuracy: 0.6164
# Epoch 372, CIFAR-10 Batch 4:  Loss:     0.5878, Train Accuracy:     0.8041, Validation Accuracy: 0.6048
# Epoch 372, CIFAR-10 Batch 5:  Loss:     0.5887, Train Accuracy:     0.7770, Validation Accuracy: 0.6082
# Epoch 373, CIFAR-10 Batch 1:  Loss:     0.6795, Train Accuracy:     0.7568, Validation Accuracy: 0.6090
# Epoch 373, CIFAR-10 Batch 2:  Loss:     0.5841, Train Accuracy:     0.8176, Validation Accuracy: 0.6028
# Epoch 373, CIFAR-10 Batch 3:  Loss:     0.5254, Train Accuracy:     0.8243, Validation Accuracy: 0.6100
# Epoch 373, CIFAR-10 Batch 4:  Loss:     0.5993, Train Accuracy:     0.7905, Validation Accuracy: 0.6110
# Epoch 373, CIFAR-10 Batch 5:  Loss:     0.6035, Train Accuracy:     0.7939, Validation Accuracy: 0.6050
# Epoch 374, CIFAR-10 Batch 1:  Loss:     0.6982, Train Accuracy:     0.7230, Validation Accuracy: 0.6074
# Epoch 374, CIFAR-10 Batch 2:  Loss:     0.5700, Train Accuracy:     0.8209, Validation Accuracy: 0.6114
# Epoch 374, CIFAR-10 Batch 3:  Loss:     0.5044, Train Accuracy:     0.8243, Validation Accuracy: 0.6106
# Epoch 374, CIFAR-10 Batch 4:  Loss:     0.5769, Train Accuracy:     0.8007, Validation Accuracy: 0.6084
# Epoch 374, CIFAR-10 Batch 5:  Loss:     0.6274, Train Accuracy:     0.7635, Validation Accuracy: 0.6034
# Epoch 375, CIFAR-10 Batch 1:  Loss:     0.6599, Train Accuracy:     0.7534, Validation Accuracy: 0.6204
# Epoch 375, CIFAR-10 Batch 2:  Loss:     0.5935, Train Accuracy:     0.8108, Validation Accuracy: 0.5984
# Epoch 375, CIFAR-10 Batch 3:  Loss:     0.5095, Train Accuracy:     0.8378, Validation Accuracy: 0.6134
# Epoch 375, CIFAR-10 Batch 4:  Loss:     0.5511, Train Accuracy:     0.8277, Validation Accuracy: 0.6102
# Epoch 375, CIFAR-10 Batch 5:  Loss:     0.6038, Train Accuracy:     0.7872, Validation Accuracy: 0.6088
# Epoch 376, CIFAR-10 Batch 1:  Loss:     0.6593, Train Accuracy:     0.7466, Validation Accuracy: 0.6140
# Epoch 376, CIFAR-10 Batch 2:  Loss:     0.5737, Train Accuracy:     0.8041, Validation Accuracy: 0.6002
# Epoch 376, CIFAR-10 Batch 3:  Loss:     0.5083, Train Accuracy:     0.8345, Validation Accuracy: 0.6172
# Epoch 376, CIFAR-10 Batch 4:  Loss:     0.5650, Train Accuracy:     0.8142, Validation Accuracy: 0.6124
# Epoch 376, CIFAR-10 Batch 5:  Loss:     0.6548, Train Accuracy:     0.7736, Validation Accuracy: 0.6028
# Epoch 377, CIFAR-10 Batch 1:  Loss:     0.6892, Train Accuracy:     0.7297, Validation Accuracy: 0.6096
# Epoch 377, CIFAR-10 Batch 2:  Loss:     0.5752, Train Accuracy:     0.8142, Validation Accuracy: 0.6012
# Epoch 377, CIFAR-10 Batch 3:  Loss:     0.5185, Train Accuracy:     0.8480, Validation Accuracy: 0.6114
# Epoch 377, CIFAR-10 Batch 4:  Loss:     0.5394, Train Accuracy:     0.8277, Validation Accuracy: 0.6154
# Epoch 377, CIFAR-10 Batch 5:  Loss:     0.5799, Train Accuracy:     0.7804, Validation Accuracy: 0.6072
# Epoch 378, CIFAR-10 Batch 1:  Loss:     0.6755, Train Accuracy:     0.7399, Validation Accuracy: 0.6098
# Epoch 378, CIFAR-10 Batch 2:  Loss:     0.5430, Train Accuracy:     0.8243, Validation Accuracy: 0.6026
# Epoch 378, CIFAR-10 Batch 3:  Loss:     0.4902, Train Accuracy:     0.8514, Validation Accuracy: 0.6158
# Epoch 378, CIFAR-10 Batch 4:  Loss:     0.5356, Train Accuracy:     0.8176, Validation Accuracy: 0.6138
# Epoch 378, CIFAR-10 Batch 5:  Loss:     0.5902, Train Accuracy:     0.7939, Validation Accuracy: 0.6096
# Epoch 379, CIFAR-10 Batch 1:  Loss:     0.6821, Train Accuracy:     0.7500, Validation Accuracy: 0.6062
# Epoch 379, CIFAR-10 Batch 2:  Loss:     0.5692, Train Accuracy:     0.8243, Validation Accuracy: 0.6066
# Epoch 379, CIFAR-10 Batch 3:  Loss:     0.5041, Train Accuracy:     0.8378, Validation Accuracy: 0.6082
# Epoch 379, CIFAR-10 Batch 4:  Loss:     0.5326, Train Accuracy:     0.8345, Validation Accuracy: 0.6152
# Epoch 379, CIFAR-10 Batch 5:  Loss:     0.6060, Train Accuracy:     0.7736, Validation Accuracy: 0.6118
# Epoch 380, CIFAR-10 Batch 1:  Loss:     0.6549, Train Accuracy:     0.7500, Validation Accuracy: 0.6124
# Epoch 380, CIFAR-10 Batch 2:  Loss:     0.5612, Train Accuracy:     0.8041, Validation Accuracy: 0.6054
# Epoch 380, CIFAR-10 Batch 3:  Loss:     0.5008, Train Accuracy:     0.8446, Validation Accuracy: 0.6170
# Epoch 380, CIFAR-10 Batch 4:  Loss:     0.5354, Train Accuracy:     0.8378, Validation Accuracy: 0.6018
# Epoch 380, CIFAR-10 Batch 5:  Loss:     0.5849, Train Accuracy:     0.7939, Validation Accuracy: 0.6156
# Epoch 381, CIFAR-10 Batch 1:  Loss:     0.7010, Train Accuracy:     0.7466, Validation Accuracy: 0.6078
# Epoch 381, CIFAR-10 Batch 2:  Loss:     0.5511, Train Accuracy:     0.8311, Validation Accuracy: 0.6142
# Epoch 381, CIFAR-10 Batch 3:  Loss:     0.4980, Train Accuracy:     0.8480, Validation Accuracy: 0.6194
# Epoch 381, CIFAR-10 Batch 4:  Loss:     0.5372, Train Accuracy:     0.8412, Validation Accuracy: 0.6114
# Epoch 381, CIFAR-10 Batch 5:  Loss:     0.5868, Train Accuracy:     0.7838, Validation Accuracy: 0.6066
# Epoch 382, CIFAR-10 Batch 1:  Loss:     0.6531, Train Accuracy:     0.7500, Validation Accuracy: 0.6100
# Epoch 382, CIFAR-10 Batch 2:  Loss:     0.5448, Train Accuracy:     0.8345, Validation Accuracy: 0.6116
# Epoch 382, CIFAR-10 Batch 3:  Loss:     0.5111, Train Accuracy:     0.8378, Validation Accuracy: 0.6116
# Epoch 382, CIFAR-10 Batch 4:  Loss:     0.5410, Train Accuracy:     0.8378, Validation Accuracy: 0.6118
# Epoch 382, CIFAR-10 Batch 5:  Loss:     0.5943, Train Accuracy:     0.7905, Validation Accuracy: 0.6136
# Epoch 383, CIFAR-10 Batch 1:  Loss:     0.6643, Train Accuracy:     0.7500, Validation Accuracy: 0.6100
# Epoch 383, CIFAR-10 Batch 2:  Loss:     0.5848, Train Accuracy:     0.7905, Validation Accuracy: 0.6048
# Epoch 383, CIFAR-10 Batch 3:  Loss:     0.5021, Train Accuracy:     0.8378, Validation Accuracy: 0.6110
# Epoch 383, CIFAR-10 Batch 4:  Loss:     0.5445, Train Accuracy:     0.8209, Validation Accuracy: 0.6114
# Epoch 383, CIFAR-10 Batch 5:  Loss:     0.5939, Train Accuracy:     0.7905, Validation Accuracy: 0.6166
# Epoch 384, CIFAR-10 Batch 1:  Loss:     0.6303, Train Accuracy:     0.7669, Validation Accuracy: 0.6142
# Epoch 384, CIFAR-10 Batch 2:  Loss:     0.5731, Train Accuracy:     0.8176, Validation Accuracy: 0.6060
# Epoch 384, CIFAR-10 Batch 3:  Loss:     0.4913, Train Accuracy:     0.8547, Validation Accuracy: 0.6066
# Epoch 384, CIFAR-10 Batch 4:  Loss:     0.5358, Train Accuracy:     0.8243, Validation Accuracy: 0.6128
# Epoch 384, CIFAR-10 Batch 5:  Loss:     0.5810, Train Accuracy:     0.7939, Validation Accuracy: 0.6152
# Epoch 385, CIFAR-10 Batch 1:  Loss:     0.6207, Train Accuracy:     0.7703, Validation Accuracy: 0.6144
# Epoch 385, CIFAR-10 Batch 2:  Loss:     0.5381, Train Accuracy:     0.8581, Validation Accuracy: 0.6122
# Epoch 385, CIFAR-10 Batch 3:  Loss:     0.4957, Train Accuracy:     0.8547, Validation Accuracy: 0.6172
# Epoch 385, CIFAR-10 Batch 4:  Loss:     0.5388, Train Accuracy:     0.8243, Validation Accuracy: 0.6126
# Epoch 385, CIFAR-10 Batch 5:  Loss:     0.5884, Train Accuracy:     0.7905, Validation Accuracy: 0.6090
# Epoch 386, CIFAR-10 Batch 1:  Loss:     0.6816, Train Accuracy:     0.7297, Validation Accuracy: 0.6036
# Epoch 386, CIFAR-10 Batch 2:  Loss:     0.5800, Train Accuracy:     0.8007, Validation Accuracy: 0.6014
# Epoch 386, CIFAR-10 Batch 3:  Loss:     0.5207, Train Accuracy:     0.8243, Validation Accuracy: 0.6116
# Epoch 386, CIFAR-10 Batch 4:  Loss:     0.5489, Train Accuracy:     0.8243, Validation Accuracy: 0.6022
# Epoch 386, CIFAR-10 Batch 5:  Loss:     0.5888, Train Accuracy:     0.7838, Validation Accuracy: 0.6150
# Epoch 387, CIFAR-10 Batch 1:  Loss:     0.6420, Train Accuracy:     0.7601, Validation Accuracy: 0.6110
# Epoch 387, CIFAR-10 Batch 2:  Loss:     0.5533, Train Accuracy:     0.8243, Validation Accuracy: 0.6090
# Epoch 387, CIFAR-10 Batch 3:  Loss:     0.5142, Train Accuracy:     0.8446, Validation Accuracy: 0.6132
# Epoch 387, CIFAR-10 Batch 4:  Loss:     0.5548, Train Accuracy:     0.8243, Validation Accuracy: 0.6122
# Epoch 387, CIFAR-10 Batch 5:  Loss:     0.5932, Train Accuracy:     0.7939, Validation Accuracy: 0.6114
# Epoch 388, CIFAR-10 Batch 1:  Loss:     0.6739, Train Accuracy:     0.7399, Validation Accuracy: 0.6038
# Epoch 388, CIFAR-10 Batch 2:  Loss:     0.5738, Train Accuracy:     0.8041, Validation Accuracy: 0.6100
# Epoch 388, CIFAR-10 Batch 3:  Loss:     0.4860, Train Accuracy:     0.8480, Validation Accuracy: 0.6158
# Epoch 388, CIFAR-10 Batch 4:  Loss:     0.5363, Train Accuracy:     0.8176, Validation Accuracy: 0.6070
# Epoch 388, CIFAR-10 Batch 5:  Loss:     0.5766, Train Accuracy:     0.7905, Validation Accuracy: 0.6218
# Epoch 389, CIFAR-10 Batch 1:  Loss:     0.6439, Train Accuracy:     0.7534, Validation Accuracy: 0.6124
# Epoch 389, CIFAR-10 Batch 2:  Loss:     0.5469, Train Accuracy:     0.8378, Validation Accuracy: 0.6088
# Epoch 389, CIFAR-10 Batch 3:  Loss:     0.5035, Train Accuracy:     0.8378, Validation Accuracy: 0.6116
# Epoch 389, CIFAR-10 Batch 4:  Loss:     0.5278, Train Accuracy:     0.8378, Validation Accuracy: 0.6086
# Epoch 389, CIFAR-10 Batch 5:  Loss:     0.5911, Train Accuracy:     0.7872, Validation Accuracy: 0.6116
# Epoch 390, CIFAR-10 Batch 1:  Loss:     0.6200, Train Accuracy:     0.7601, Validation Accuracy: 0.6156
# Epoch 390, CIFAR-10 Batch 2:  Loss:     0.5432, Train Accuracy:     0.8176, Validation Accuracy: 0.6176
# Epoch 390, CIFAR-10 Batch 3:  Loss:     0.4907, Train Accuracy:     0.8480, Validation Accuracy: 0.6188
# Epoch 390, CIFAR-10 Batch 4:  Loss:     0.5282, Train Accuracy:     0.8480, Validation Accuracy: 0.6110
# Epoch 390, CIFAR-10 Batch 5:  Loss:     0.5851, Train Accuracy:     0.7804, Validation Accuracy: 0.6114
# Epoch 391, CIFAR-10 Batch 1:  Loss:     0.6347, Train Accuracy:     0.7669, Validation Accuracy: 0.6136
# Epoch 391, CIFAR-10 Batch 2:  Loss:     0.5479, Train Accuracy:     0.8209, Validation Accuracy: 0.6060
# Epoch 391, CIFAR-10 Batch 3:  Loss:     0.4978, Train Accuracy:     0.8446, Validation Accuracy: 0.6122
# Epoch 391, CIFAR-10 Batch 4:  Loss:     0.5181, Train Accuracy:     0.8514, Validation Accuracy: 0.6110
# Epoch 391, CIFAR-10 Batch 5:  Loss:     0.5820, Train Accuracy:     0.7973, Validation Accuracy: 0.6142
# Epoch 392, CIFAR-10 Batch 1:  Loss:     0.6501, Train Accuracy:     0.7601, Validation Accuracy: 0.6094
# Epoch 392, CIFAR-10 Batch 2:  Loss:     0.5268, Train Accuracy:     0.8480, Validation Accuracy: 0.6062
# Epoch 392, CIFAR-10 Batch 3:  Loss:     0.5214, Train Accuracy:     0.8243, Validation Accuracy: 0.6144
# Epoch 392, CIFAR-10 Batch 4:  Loss:     0.5342, Train Accuracy:     0.8277, Validation Accuracy: 0.6116
# Epoch 392, CIFAR-10 Batch 5:  Loss:     0.5838, Train Accuracy:     0.7872, Validation Accuracy: 0.6136
# Epoch 393, CIFAR-10 Batch 1:  Loss:     0.6428, Train Accuracy:     0.7500, Validation Accuracy: 0.6124
# Epoch 393, CIFAR-10 Batch 2:  Loss:     0.5361, Train Accuracy:     0.8277, Validation Accuracy: 0.6088
# Epoch 393, CIFAR-10 Batch 3:  Loss:     0.4805, Train Accuracy:     0.8514, Validation Accuracy: 0.6174
# Epoch 393, CIFAR-10 Batch 4:  Loss:     0.5227, Train Accuracy:     0.8243, Validation Accuracy: 0.6174
# Epoch 393, CIFAR-10 Batch 5:  Loss:     0.5754, Train Accuracy:     0.8074, Validation Accuracy: 0.6076
# Epoch 394, CIFAR-10 Batch 1:  Loss:     0.6364, Train Accuracy:     0.7500, Validation Accuracy: 0.6152
# Epoch 394, CIFAR-10 Batch 2:  Loss:     0.5857, Train Accuracy:     0.8243, Validation Accuracy: 0.6042
# Epoch 394, CIFAR-10 Batch 3:  Loss:     0.4910, Train Accuracy:     0.8547, Validation Accuracy: 0.6140
# Epoch 394, CIFAR-10 Batch 4:  Loss:     0.5487, Train Accuracy:     0.8142, Validation Accuracy: 0.6068
# Epoch 394, CIFAR-10 Batch 5:  Loss:     0.5853, Train Accuracy:     0.8041, Validation Accuracy: 0.6128
# Epoch 395, CIFAR-10 Batch 1:  Loss:     0.6429, Train Accuracy:     0.7770, Validation Accuracy: 0.6158
# Epoch 395, CIFAR-10 Batch 2:  Loss:     0.5274, Train Accuracy:     0.8378, Validation Accuracy: 0.6064
# Epoch 395, CIFAR-10 Batch 3:  Loss:     0.4862, Train Accuracy:     0.8480, Validation Accuracy: 0.6188
# Epoch 395, CIFAR-10 Batch 4:  Loss:     0.5207, Train Accuracy:     0.8412, Validation Accuracy: 0.6064
# Epoch 395, CIFAR-10 Batch 5:  Loss:     0.6007, Train Accuracy:     0.7736, Validation Accuracy: 0.6154
# Epoch 396, CIFAR-10 Batch 1:  Loss:     0.6381, Train Accuracy:     0.7466, Validation Accuracy: 0.6092
# Epoch 396, CIFAR-10 Batch 2:  Loss:     0.5343, Train Accuracy:     0.8378, Validation Accuracy: 0.6114
# Epoch 396, CIFAR-10 Batch 3:  Loss:     0.5045, Train Accuracy:     0.8243, Validation Accuracy: 0.6104
# Epoch 396, CIFAR-10 Batch 4:  Loss:     0.5261, Train Accuracy:     0.8243, Validation Accuracy: 0.6076
# Epoch 396, CIFAR-10 Batch 5:  Loss:     0.5884, Train Accuracy:     0.8007, Validation Accuracy: 0.6134
# Epoch 397, CIFAR-10 Batch 1:  Loss:     0.6124, Train Accuracy:     0.7703, Validation Accuracy: 0.6172
# Epoch 397, CIFAR-10 Batch 2:  Loss:     0.5459, Train Accuracy:     0.8378, Validation Accuracy: 0.6068
# Epoch 397, CIFAR-10 Batch 3:  Loss:     0.4889, Train Accuracy:     0.8412, Validation Accuracy: 0.6136
# Epoch 397, CIFAR-10 Batch 4:  Loss:     0.5386, Train Accuracy:     0.8209, Validation Accuracy: 0.6096
# Epoch 397, CIFAR-10 Batch 5:  Loss:     0.5656, Train Accuracy:     0.8007, Validation Accuracy: 0.6124
# Epoch 398, CIFAR-10 Batch 1:  Loss:     0.6306, Train Accuracy:     0.7534, Validation Accuracy: 0.6156
# Epoch 398, CIFAR-10 Batch 2:  Loss:     0.5250, Train Accuracy:     0.8480, Validation Accuracy: 0.6106
# Epoch 398, CIFAR-10 Batch 3:  Loss:     0.4613, Train Accuracy:     0.8581, Validation Accuracy: 0.6138
# Epoch 398, CIFAR-10 Batch 4:  Loss:     0.5250, Train Accuracy:     0.8446, Validation Accuracy: 0.6026
# Epoch 398, CIFAR-10 Batch 5:  Loss:     0.5835, Train Accuracy:     0.7939, Validation Accuracy: 0.6138
# Epoch 399, CIFAR-10 Batch 1:  Loss:     0.6300, Train Accuracy:     0.7703, Validation Accuracy: 0.6054
# Epoch 399, CIFAR-10 Batch 2:  Loss:     0.5262, Train Accuracy:     0.8378, Validation Accuracy: 0.6100
# Epoch 399, CIFAR-10 Batch 3:  Loss:     0.5041, Train Accuracy:     0.8345, Validation Accuracy: 0.6044
# Epoch 399, CIFAR-10 Batch 4:  Loss:     0.5383, Train Accuracy:     0.8412, Validation Accuracy: 0.6144
# Epoch 399, CIFAR-10 Batch 5:  Loss:     0.5605, Train Accuracy:     0.7905, Validation Accuracy: 0.6094
# Epoch 400, CIFAR-10 Batch 1:  Loss:     0.6334, Train Accuracy:     0.7568, Validation Accuracy: 0.6140
# Epoch 400, CIFAR-10 Batch 2:  Loss:     0.5303, Train Accuracy:     0.8378, Validation Accuracy: 0.6074
# Epoch 400, CIFAR-10 Batch 3:  Loss:     0.4963, Train Accuracy:     0.8412, Validation Accuracy: 0.6136
# Epoch 400, CIFAR-10 Batch 4:  Loss:     0.5313, Train Accuracy:     0.8378, Validation Accuracy: 0.6060
# Epoch 400, CIFAR-10 Batch 5:  Loss:     0.5832, Train Accuracy:     0.7838, Validation Accuracy: 0.6168

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %% [markdown]
# # 检查点
#
# 该模型已经被存储到你的硬盘中。
#
# ## 测试模型
#
# 这部分将在测试数据集上测试你的模型。这边得到的准确率将作为你的最终准确率。你应该得到一个高于 50% 准确率。如果它没有超过 50%，那么你需要继续调整模型架构及参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6148035377264023

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.

# %% [markdown]
# ## 为什么仅有 50%~ 80% 的准确率？
#
# 你也许会觉得奇怪，为什么你的准确率总是提高不上去。对于简单的 CNN 网络而言，50% 并非是很差的表现。纯粹的猜测只会得到 10% 的准确率（因为一共有 10 类）。这是因为还有许多许多能够应用到你模型的技巧。在你做完了该项目之后，你可以探索探索我们给你推荐的一些方法。
#
#
# ## 提交该项目
#
# 在提交项目前，请确保你在运行了所有的 cell 之后保存了项目。将项目储存为 "image_classification.ipynb" 并导出为一个 HTML 文件。你可以再菜单栏中选择 File -> Download as 进行导出。请将 "helper.py" 及  "problem_unittests.py" 文件也放在你的提交文件中。
